# %% [markdown]
# # WeatherPy
# ----
#
# #### Three Observable Trends
# * Trend 1 - The cities near the equator are warmer. This trend is observed by: Latitude vs. Temperature plot. Cities that have the higher temperature are clustered near the equator (0) latitude.
#
# * Trend 2 - During the December month, cities in the Northern Hemisphere that are further away from the equator are colder. This trend is observed in the plot: Northern Hemisphere - Max Temp vs. Latitude Linear Regression.
#
# * Trend 3 - Wind, Humidity, and Cloudiness do not seem to change much per city location, whether Northern or Southern Hemispheres. This trend is observed in the plots for both Northern and Southern Hemispheres for: Humidity (%) vs. Latitude Linear Regression,  Cloudiness (%) vs. Latitude Linear Regression, and Wind Speed (mph) vs. Latitude Linear Regression.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import sys
sys.path.append('../')

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = 'output_data/cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url + city).json()
# Taking a look at the data for a city
print(response)
# Out:
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 25.76, 'feels_like': 27.46, 'temp_min': 23.89, 'temp_max': 27, 'pressure': 1017, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 2.6, 'deg': 140}, 'clouds': {'all': 90}, 'dt': 1607901255, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1607877990, 'sunset': 1607917410}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set up lists to hold response info
city_name = []
city_lat = []
city_lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
index_counter = 0
set_counter = 1

# %%
print('Beginning Data Retrieval ')
print('-----------------------------')

# Loop through the list of cities and perform a request for data on each...
for index, city in enumerate(cities):
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    response = requests.get(query_url + city).json()
    try:
       
        city_name.append(response['name'])
        city_lat.append(response['coord']['lat'])
        city_lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        else:
            index_counter = index_counter + 1
  
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}")
    except:
        print('City not found. Skipping...')
        
print('-----------------------------')
print('Data Retrieval Complete ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | leh
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | san antero
# Processing Record 6 of Set 1 | lompoc
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 9 of Set 1 | meadow lake
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | port lincoln
# City not found. Skipping...
# Processing Record 12 of Set 1 | porbandar
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | muros
# Processing Record 16 of Set 1 | bluff
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | glendive
# City not found. Skipping...
# Processing Record 20 of Set 1 | natchitoches
# Processing Record 21 of Set 1 | umea
# Processing Record 22 of Set 1 | dumbravita
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | zelenoborskiy
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | samfya
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | grand gaube
# Processing Record 30 of Set 1 | waingapu
# Processing Record 16 of Set 4 | antofagasta
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | beisfjord
# Processing Record 21 of Set 4 | vanimo
# Processing Record 22 of Set 4 | namibe
# Processing Record 23 of Set 4 | cairns
# Processing Record 24 of Set 4 | hervey bay
# Processing Record 25 of Set 4 | gudivada
# Processing Record 26 of Set 4 | udalguri
# Processing Record 27 of Set 4 | hobyo
# Processing Record 28 of Set 4 | lagoa
# Processing Record 29 of Set 4 | krasnouralsk
# Processing Record 30 of Set 4 | nanortalik
# Processing Record 31 of Set 4 | lazaro cardenas
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | harper
# Processing Record 34 of Set 4 | touros
# Processing Record 35 of Set 4 | the valley
# Processing Record 36 of Set 4 | bereda
# Processing Record 37 of Set 4 | oktyabrskiy
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | boca do acre
# Processing Record 40 of Set 4 | port hedland
# Processing Record 41 of Set 4 | codrington
# Processing Record 42 of Set 4 | torbay
# Processing Record 43 of Set 4 | novaya lyalya
# Processing Record 44 of Set 4 | carnarvon
# Processing Record 45 of Set 4 | vila franca do campo
# Processing Record 46 of Set 4 | flin flon
# Processing Record 47 of Set 4 | can tho
# Processing Record 48 of Set 4 | lasa
# Processing Record 49 of Set 4 | vagay
# Processing Record 50 of Set 4 | takoradi
# City not found. Skipping...
# Processing Record 0 of Set 5 | isla vista
# Processing Record 1 of Set 5 | ayan
# Processing Record 2 of Set 5 | ponta do sol
# City not found. Skipping...
# Processing Record 3 of Set 5 | necochea
# Processing Record 4 of Set 5 | tucumcari
# Processing Record 5 of Set 5 | arlit
# Processing Record 6 of Set 5 | dukat
# Processing Record 7 of Set 5 | mecca
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | hearst
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | mayo
# Processing Record 12 of Set 5 | pella
# Processing Record 13 of Set 5 | longhua
# Processing Record 14 of Set 5 | bantou
# Processing Record 15 of Set 5 | beira
# Processing Record 16 of Set 5 | lavrentiya
# Processing Record 17 of Set 5 | kropotkin
# Processing Record 18 of Set 5 | wageningen
# Processing Record 19 of Set 5 | berlevag
# Processing Record 20 of Set 5 | krasnoselkup
# Processing Record 21 of Set 5 | trofors
# Processing Record 22 of Set 5 | margate
# City not found. Skipping...
# Processing Record 23 of Set 5 | nantucket
# Processing Record 24 of Set 5 | kieta
# Processing Record 25 of Set 5 | bozoum
# Processing Record 26 of Set 5 | nsanje
# Processing Record 27 of Set 5 | port elizabeth
# City not found. Skipping...
# Processing Record 28 of Set 5 | cockburn town
# Processing Record 29 of Set 5 | beloha
# Processing Record 30 of Set 5 | ndende
# Processing Record 31 of Set 5 | awbari
# Processing Record 32 of Set 5 | hofn
# Processing Record 33 of Set 5 | gondar
# Processing Record 34 of Set 5 | gat
# Processing Record 35 of Set 5 | valdivia
# Processing Record 36 of Set 5 | pacific grove
# Processing Record 37 of Set 5 | wanning
# City not found. Skipping...
# Processing Record 38 of Set 5 | kamenka
# Processing Record 39 of Set 5 | mount isa
# Processing Record 40 of Set 5 | artyom
# Processing Record 41 of Set 5 | severobaykalsk
# Processing Record 42 of Set 5 | srednekolymsk
# Processing Record 43 of Set 5 | pouebo
# Processing Record 44 of Set 5 | brookhaven
# Processing Record 45 of Set 5 | great yarmouth
# Processing Record 46 of Set 5 | omsukchan
# Processing Record 47 of Set 5 | sobolevo
# Processing Record 48 of Set 5 | santhia
# Processing Record 49 of Set 5 | mende
# Processing Record 50 of Set 5 | san jose
# Processing Record 0 of Set 6 | honiara
# Processing Record 1 of Set 6 | kargil
# Processing Record 2 of Set 6 | talnakh
# Processing Record 3 of Set 6 | suntar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 6 | novo aripuana
# Processing Record 5 of Set 6 | myitkyina
# Processing Record 6 of Set 6 | port blair
# Processing Record 7 of Set 6 | roros
# Processing Record 8 of Set 6 | marquette
# Processing Record 9 of Set 6 | drayton valley
# Processing Record 10 of Set 6 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 11 of Set 6 | aklavik
# Processing Record 12 of Set 6 | turbat
# Processing Record 13 of Set 6 | bulawayo
# Processing Record 14 of Set 6 | camacha
# Processing Record 15 of Set 6 | kemijarvi
# Processing Record 16 of Set 6 | xuddur
# Processing Record 17 of Set 6 | russell
# Processing Record 18 of Set 6 | fasa
# Processing Record 19 of Set 6 | avera
# Processing Record 20 of Set 6 | mula
# Processing Record 21 of Set 6 | sanchazi
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | pinar del rio
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | kodiak
# Processing Record 26 of Set 6 | north bend
# Processing Record 27 of Set 6 | saurimo
# Processing Record 28 of Set 6 | saint anthony
# Processing Record 29 of Set 6 | padang
# Processing Record 30 of Set 6 | sao jose da coroa grande
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | bhatkal
# Processing Record 33 of Set 6 | yenagoa
# Processing Record 34 of Set 6 | corrente
# Processing Record 35 of Set 6 | longyearbyen
# Processing Record 36 of Set 6 | mookane
# Processing Record 37 of Set 6 | lichinga
# Processing Record 38 of Set 6 | urusha
# Processing Record 39 of Set 6 | bandarbeyla
# Processing Record 40 of Set 6 | lock haven
# Processing Record 41 of Set 6 | wuwei
# Processing Record 42 of Set 6 | guanica
# Processing Record 43 of Set 6 | hualmay
# Processing Record 44 of Set 6 | ninghai
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | karakol
# City not found. Skipping...
# Processing Record 47 of Set 6 | labuhan
# Processing Record 48 of Set 6 | amapa
# Processing Record 49 of Set 6 | dingle
# Processing Record 50 of Set 6 | neepawa
# Processing Record 0 of Set 7 | paso de los toros
# Processing Record 1 of Set 7 | kommunisticheskiy
# Processing Record 2 of Set 7 | coquimbo
# Processing Record 3 of Set 7 | bintulu
# Processing Record 4 of Set 7 | eucaliptus
# Processing Record 45 of Set 9 | praia da vitoria
# Processing Record 46 of Set 9 | clifton springs
# Processing Record 47 of Set 9 | kahului
# Processing Record 48 of Set 9 | wajir
# Processing Record 49 of Set 9 | belaya gora
# Processing Record 50 of Set 9 | vidalia
# Processing Record 0 of Set 10 | kailua
# Processing Record 1 of Set 10 | brae
# Processing Record 2 of Set 10 | dwarka
# Processing Record 3 of Set 10 | ambon
# Processing Record 4 of Set 10 | trairi
# Processing Record 5 of Set 10 | mangan
# Processing Record 6 of Set 10 | bage
# Processing Record 7 of Set 10 | manuk mangkaw
# Processing Record 8 of Set 10 | turayf
# Processing Record 9 of Set 10 | skibbereen
# Processing Record 10 of Set 10 | mokrousovo
# Processing Record 11 of Set 10 | berdigestyakh
# Processing Record 12 of Set 10 | raga
# Processing Record 13 of Set 10 | trat
# Processing Record 14 of Set 10 | kirkwood
# Processing Record 15 of Set 10 | huilong
# Processing Record 16 of Set 10 | north myrtle beach
# Processing Record 17 of Set 10 | temir
# Processing Record 18 of Set 10 | north platte
# Processing Record 19 of Set 10 | roberval
# Processing Record 20 of Set 10 | valley station
# Processing Record 21 of Set 10 | black river
# Processing Record 22 of Set 10 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 23 of Set 10 | ust-koksa
# Processing Record 24 of Set 10 | iqaluit
# Processing Record 25 of Set 10 | meru
# City not found. Skipping...
# Processing Record 26 of Set 10 | buala
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | irshava
# Processing Record 29 of Set 10 | mountain home
# Processing Record 30 of Set 10 | mitsamiouli
# Processing Record 31 of Set 10 | akyab
# Processing Record 32 of Set 10 | coahuayana
# Processing Record 33 of Set 10 | maun
# Processing Record 34 of Set 10 | kiambu
# Processing Record 35 of Set 10 | tilichiki
# Processing Record 36 of Set 10 | deputatskiy
# Processing Record 37 of Set 10 | camapua
# Processing Record 38 of Set 10 | vestmanna
# Processing Record 39 of Set 10 | karratha
# Processing Record 40 of Set 10 | villazon
# Processing Record 41 of Set 10 | vershino-darasunskiy
# Processing Record 42 of Set 10 | ilhabela
# Processing Record 43 of Set 10 | cravo norte
# Processing Record 44 of Set 10 | qaqortoq
# Processing Record 45 of Set 10 | goderich
# Processing Record 46 of Set 10 | ballina
# Processing Record 47 of Set 10 | balykshi
# Processing Record 48 of Set 10 | mokhsogollokh
# Processing Record 49 of Set 10 | kembe
# Processing Record 50 of Set 10 | synya
# City not found. Skipping...
# Processing Record 0 of Set 11 | husavik
# Processing Record 1 of Set 11 | tingi
# Processing Record 2 of Set 11 | mayor pablo lagerenza
# Processing Record 3 of Set 11 | slantsy
# Processing Record 4 of Set 11 | denpasar
# Processing Record 5 of Set 11 | nabire
# Processing Record 6 of Set 11 | athmallik
# Processing Record 7 of Set 11 | naryan-mar
# Processing Record 8 of Set 11 | sola
# Processing Record 9 of Set 11 | havre-saint-pierre
# Processing Record 10 of Set 11 | nishihara
# Processing Record 11 of Set 11 | alice springs
# Processing Record 12 of Set 11 | acapulco
# Processing Record 13 of Set 11 | hailin
# Processing Record 14 of Set 11 | espanola
# Processing Record 15 of Set 11 | jiblah
# Processing Record 16 of Set 11 | farah
# Processing Record 17 of Set 11 | athabasca
# Processing Record 18 of Set 11 | asau
# Processing Record 19 of Set 11 | innisfail
# Processing Record 20 of Set 11 | sibolga
# Processing Record 21 of Set 11 | matamoros
# Processing Record 22 of Set 11 | haguenau
# Processing Record 23 of Set 11 | matucana
# Processing Record 24 of Set 11 | hailun
# City not found. Skipping...
# Processing Record 25 of Set 11 | bosaso
# Processing Record 26 of Set 11 | sri aman
# Processing Record 27 of Set 11 | martapura
# Processing Record 28 of Set 11 | ostersund
# Processing Record 29 of Set 11 | riwaka
# Processing Record 30 of Set 11 | portland
# Processing Record 31 of Set 11 | tessalit
# City not found. Skipping...
# Processing Record 32 of Set 11 | suslovo
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | rupnagar
# Processing Record 35 of Set 11 | voi
# Processing Record 36 of Set 11 | laguna
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 11 | port augusta
# Processing Record 38 of Set 11 | umm lajj
# Processing Record 39 of Set 11 | erenhot
# Processing Record 40 of Set 11 | christchurch
# Processing Record 41 of Set 11 | paraiso
# Processing Record 42 of Set 11 | antonina
# Processing Record 43 of Set 11 | pangody
# Processing Record 44 of Set 11 | san cristobal
# Processing Record 45 of Set 11 | longjiang
# Processing Record 46 of Set 11 | stepnoye
# Processing Record 47 of Set 11 | mhlume
# Processing Record 48 of Set 11 | nurota
# Processing Record 49 of Set 11 | aleysk
# Processing Record 50 of Set 11 | namatanai
# Processing Record 0 of Set 12 | palu
# Processing Record 1 of Set 12 | saint-louis
# Processing Record 2 of Set 12 | sawakin
# Processing Record 3 of Set 12 | vanderhoof
# Processing Record 4 of Set 12 | manokwari
# Processing Record 5 of Set 12 | campoverde
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame
city_df = pd.DataFrame({"City": city_name, "Lat": city_lat , "Lng": city_lng, "Max Temp": max_temp, "Humidity": humidity , 
                        "Cloudiness":cloudiness , "Wind Speed":wind_speed, "Country":country , "Date":date  })

# %%
#city_df.head()

# %%
# Converting Celsius to Fahrenheit for changing column max temp to F
def to_fahr(C):
    return (C*9/5) + 32
city_convert_temp = city_df[['Max Temp']].apply(to_fahr)
# Getting list for Fahrenheit temperatures
temp_f = city_convert_temp['Max Temp'].to_list()

# %%
#city_convert_temp

# %%
#adding column of max tem (F) to dataframe
city_df['Max Temp_(F)'] =  city_convert_temp
#city_df

# %%
#dropping max temp for celsius
city_df.drop(['Max Temp'], axis = 1, inplace = True)
#city_df

# %%
# renaming column to Max Temp
city_df.rename(columns = {'Max Temp_(F)': "Max Temp"}, inplace = True)
#Displaying finished DataFrame
city_df
# Out:
#             City    Lat     Lng  Humidity  Cloudiness  Wind Speed Country  \
# 0        Qaanaaq  77.48  -69.36        92         100        2.64      GL
# 1         Hasaki  35.73  140.83        93          75        2.60      JP
# 2            Leh  34.17   77.58        63           0        0.56      IN
# 3        Ushuaia -54.80  -68.30        45          40        7.70      AR
# 4     San Antero   9.37  -75.76        81          69        4.04      CO
# ..           ...    ...     ...       ...         ...         ...     ...
# 561  Saint-Louis  16.33  -15.00        31           0        1.00      SN
# 562      Sawākin  19.11   37.33        72          15        1.12      SD
# 563   Vanderhoof  54.02 -124.02        89          95        1.31      CA
# 564    Manokwari  -0.87  134.08        73         100        1.41      ID
# 565   Campoverde  -8.48  -74.81        62          20        4.10      PE
#
#            Date  Max Temp
# 0    1607901446    24.836
# 1    1607901167    41.000
# 2    1607901446     3.398
# 3    1607901447    48.200
# 4    1607901447    79.718
# ..          ...       ...
# 561  1607901538    77.000
# 562  1607901538    77.936
# 563  1607901538    14.036
# 564  1607901538    82.022
# 565  1607901538    86.000
#
# [566 rows x 9 columns]

# %%
# Saving dataframe as CSV file in output_data
city_df.to_csv("output_data/city_df.csv", index = False)

# %%
# Using .describe to show statistical data
city_df.describe()
# Out:
#               Lat         Lng    Humidity  Cloudiness  Wind Speed  \
# count  566.000000  566.000000  566.000000  566.000000  566.000000
# mean    21.996078   14.666237   75.259717   54.971731    3.734470
# std     33.075574   91.299849   18.629828   38.902045    2.841802
# min    -54.800000 -179.170000   12.000000    0.000000    0.030000
# 25%     -6.122500  -68.177500   67.250000   20.000000    1.685000
# 50%     28.270000   22.630000   80.000000   68.500000    3.100000
# 75%     50.270000   92.052500   88.000000   90.000000    5.100000
# max     78.220000  179.320000  100.000000  100.000000   20.160000
#
#                Date    Max Temp
# count  5.660000e+02  566.000000
# mean   1.607901e+09   49.457551
# std    7.067984e+01   30.640213
# min    1.607901e+09  -43.024000
# 25%    1.607901e+09   30.992000
# 50%    1.607901e+09   59.297000
# 75%    1.607902e+09   75.159500
# max    1.607902e+09   87.800000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ### NOTE: per the column Humidty and Row max stating 100 is the max for Humidity, there are not any cities that have a humidity > 100%. THIS SECTION WAS SKIPPED PER THE INSTRUCTIONS.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Adding the date to the title using when the API was called.
from datetime import datetime
now = datetime.now()
timestamp = datetime.timestamp(now)
dt_object = datetime.fromtimestamp(timestamp)
print("datetime = ", dt_object)
# Out:
# datetime =  2020-12-13 17:18:59.178239

# %%
# Plotting Latitude vs. Temperature Plot
plt.scatter(city_lat, temp_f, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Max Temperature ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_Temp.png')

# %% [markdown]
# ### The Latitude vs. Temperature Plot plot shows that the temperatures in cities from the Northern Hemisphere tend to drop during the month of December 2020. The cities that are further north from the equator are colder. This plot shows there is a positive correlation between the Max Temperature and Latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plotting Latitude vs. Humidity Plot
plt.scatter(city_lat, humidity, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Humidity ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_humidity.png')

# %% [markdown]
# ### Latitude vs. Humidity Plot shows that there is no correlation between the Humidity % and Latitiude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plotting Latitude vs. Cloudiness Plot
plt.scatter(city_lat, cloudiness, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Cloudiness ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_cloudiness.png')

# %% [markdown]
# ### Latitude vs. Cloudiness Plot shows that the data points are  spread out in the graph. This means there is no trend to the data; thus there is no correlation.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plotting Latitude vs. Wind Speed Plot
plt.scatter(city_lat, wind_speed, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Wind Speed ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_windspeed.png')

# %% [markdown]
# ### Latitude vs. Wind Speed Plot shows that there is no correlation between the Wind Speed and where it is located by Latitude.###

# %% [markdown]
# ## Linear Regression

# %%
# Creating Northern and Southern Hemisphere Dataframes
N_hemisphere = city_df.loc[city_df['Lat']>=0]
S_hemisphere = city_df.loc[city_df['Lat']<0]

# %%
import scipy.stats as st

# %%
N_hemisphere
# Out:
#             City    Lat     Lng  Humidity  Cloudiness  Wind Speed Country  \
# 0        Qaanaaq  77.48  -69.36        92         100        2.64      GL
# 1         Hasaki  35.73  140.83        93          75        2.60      JP
# 2            Leh  34.17   77.58        63           0        0.56      IN
# 4     San Antero   9.37  -75.76        81          69        4.04      CO
# 5         Lompoc  34.64 -120.46        82          90        3.10      US
# ..           ...    ...     ...       ...         ...         ...     ...
# 557       Nurota  40.56   65.69       100          90        3.10      UZ
# 558       Aleysk  52.49   82.78        95          97        5.82      RU
# 561  Saint-Louis  16.33  -15.00        31           0        1.00      SN
# 562      Sawākin  19.11   37.33        72          15        1.12      SD
# 563   Vanderhoof  54.02 -124.02        89          95        1.31      CA
#
#            Date  Max Temp
# 0    1607901446    24.836
# 1    1607901167    41.000
# 2    1607901446     3.398
# 4    1607901447    79.718
# 5    1607901447    60.008
# ..          ...       ...
# 557  1607901537    21.200
# 558  1607901538     9.680
# 561  1607901538    77.000
# 562  1607901538    77.936
# 563  1607901538    14.036
#
# [396 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("N Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_maxtemp.png')
plt.show()
# Out:
# The r-value is -0.8049564080781869

# %% [markdown]
# ### The Northern Hemisphere - Max Temp vs. Latitude Linear Regression plot and negative r-value shows that there is a negative correlation. The further North the colder it is. Temperature doesen't increase along with Latitude increase, thus the correlation is a strong downhill (negative) linear relationship.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_maxtemp.png')
plt.show()
# Out:
# The r-value is 0.6010545387669757

# %% [markdown]
# ### The Southern Hemisphere - Max Temp vs. Latitude Linear Regression plot and positive r-value shows that there is a positive correlation. The closer the city is to the equator, the hotter the city is. Both latitude and Temp increase shows a moderate uphill (positive) relationship.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Humidity'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.350903454982906

# %% [markdown]
# ### The Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The further away the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a weak (positive) linear relationship.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Humidity'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.3312493167278805

# %% [markdown]
# ### The Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The closer the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a weak uphill (positive) linear relationship.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.3686586025786651

# %% [markdown]
# ### The Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The further away the city is to the equator, the % of cloudiness increases. Both latitude and cloud increase show a weak uphill (positive) relationship.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.2496139349018515

# %% [markdown]
# ### The Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression plot and r-value show that there is a positive correlation. The closer the city is to the equator, the % of cloudiness increases. The indication that both latitude and cloud increase show a weak uphill (positive) linear relationship.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(0,13),fontsize=15,color="red")
plt.ylabel('Wind Speed ')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is 0.19550420729479237

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ### The Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and positive, but low r-value show that there is a weak correlation. The r-value is almost 0 and the line is almost flat. The wind speed increases ever so slightly as the latitude increases. Both latitude and windspeed barely increase with a 0.1 r-value showing and extremly weak (positive) linear relationship.

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,13),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is -0.22116615567873305

# %% [markdown]
# ### The Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and negative r-value show that there is a negative correlation. The wind speed decreases as the latitude increases closer to the equator. Latitude increase and windspeed decrease show a weak downhill (negative) linear relationship.
