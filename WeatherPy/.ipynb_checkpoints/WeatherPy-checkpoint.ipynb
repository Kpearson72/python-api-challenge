# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = 'output_data/cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url + city).json()
# Taking a look at the data for a city
print(response)
# Out:
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 10, 'feels_like': 0.61, 'temp_min': 10, 'temp_max': 10, 'pressure': 979, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 11.8, 'deg': 230, 'gust': 17.5}, 'rain': {'1h': 0.37}, 'clouds': {'all': 40}, 'dt': 1607740216, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1607673029, 'sunset': 1607734990}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set up lists to hold response info
city_name = []
city_lat = []
city_lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
index_counter = 0
set_counter = 1

# %%
print('Beginning Data Retrieval ')
print('-----------------------------')

# Loop through the list of cities and perform a request for data on each...
for index, city in enumerate(cities):
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    response = requests.get(query_url + city).json()
    try:
       
        city_name.append(response['name'])
        city_lat.append(response['coord']['lat'])
        city_lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        else:
            index_counter = index_counter + 1
  
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}")
    except:
        print('City not found. Skipping...')
        
print('-----------------------------')
print('Data Retrieval Complete ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | oksfjord
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | zavitinsk
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | khilok
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | iralaya
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | suifenhe
# Processing Record 17 of Set 1 | basugaon
# City not found. Skipping...
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | tra vinh
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | faanui
# City not found. Skipping...
# Processing Record 26 of Set 1 | belyy yar
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | geraldton
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | hami
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | eydhafushi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | caravelas
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | padang
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | naze
# Processing Record 44 of Set 1 | abrau-dyurso
# Processing Record 45 of Set 1 | danilov
# Processing Record 46 of Set 1 | hurricane
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | seoul
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 4 | great yarmouth
# Processing Record 47 of Set 4 | dharchula
# Processing Record 48 of Set 4 | krasnaya polyana
# Processing Record 49 of Set 4 | evensk
# Processing Record 50 of Set 4 | coronon
# Processing Record 0 of Set 5 | baruun-urt
# Processing Record 1 of Set 5 | quzhou
# Processing Record 2 of Set 5 | anastasiyevskaya
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | nouadhibou
# City not found. Skipping...
# Processing Record 5 of Set 5 | maputo
# Processing Record 6 of Set 5 | rocha
# Processing Record 7 of Set 5 | sinnamary
# Processing Record 8 of Set 5 | juegang
# Processing Record 9 of Set 5 | mildura
# Processing Record 10 of Set 5 | khrebtovaya
# Processing Record 11 of Set 5 | homer
# Processing Record 12 of Set 5 | viedma
# Processing Record 13 of Set 5 | juruti
# Processing Record 14 of Set 5 | laguna
# Processing Record 15 of Set 5 | herat
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | tuktoyaktuk
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | shingu
# Processing Record 20 of Set 5 | nelson bay
# Processing Record 21 of Set 5 | zabid
# Processing Record 22 of Set 5 | baoro
# Processing Record 23 of Set 5 | sampit
# Processing Record 24 of Set 5 | tsumeb
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | outjo
# Processing Record 27 of Set 5 | chernyshevskiy
# Processing Record 28 of Set 5 | albesti
# Processing Record 29 of Set 5 | vestmanna
# Processing Record 30 of Set 5 | atbasar
# Processing Record 31 of Set 5 | axim
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | tagusao
# Processing Record 34 of Set 5 | yongan
# Processing Record 35 of Set 5 | mayumba
# Processing Record 36 of Set 5 | goundam
# Processing Record 37 of Set 5 | ketchikan
# Processing Record 38 of Set 5 | tyukhtet
# Processing Record 39 of Set 5 | avera
# Processing Record 40 of Set 5 | sioux lookout
# Processing Record 41 of Set 5 | takaka
# Processing Record 42 of Set 5 | straumen
# Processing Record 43 of Set 5 | trzebiatow
# Processing Record 44 of Set 5 | morrope
# Processing Record 45 of Set 5 | coahuayana
# Processing Record 46 of Set 5 | dingle
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | manacor
# Processing Record 49 of Set 5 | novooleksiyivka
# Processing Record 50 of Set 5 | fukue
# Processing Record 0 of Set 6 | nicolas bravo
# Processing Record 1 of Set 6 | port blair
# Processing Record 2 of Set 6 | hualmay
# Processing Record 3 of Set 6 | andra
# Processing Record 4 of Set 6 | the pas
# Processing Record 5 of Set 6 | sterling
# Processing Record 6 of Set 6 | smithers
# Processing Record 7 of Set 6 | palasa
# Processing Record 8 of Set 6 | anadyr
# Processing Record 9 of Set 6 | shangrao
# Processing Record 10 of Set 6 | rivera
# Processing Record 11 of Set 6 | kavaratti
# Processing Record 12 of Set 6 | hisua
# Processing Record 13 of Set 6 | sabha
# Processing Record 14 of Set 6 | thunder bay
# Processing Record 15 of Set 6 | hambantota
# Processing Record 16 of Set 6 | moyale
# Processing Record 17 of Set 6 | komsomolskiy
# Processing Record 18 of Set 6 | bocsa
# Processing Record 19 of Set 6 | redmond
# Processing Record 20 of Set 6 | alyangula
# Processing Record 21 of Set 6 | galveston
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | kruisfontein
# Processing Record 24 of Set 6 | port hedland
# Processing Record 25 of Set 6 | lakselv
# Processing Record 26 of Set 6 | port-cartier
# Processing Record 27 of Set 6 | la maddalena
# Processing Record 28 of Set 6 | maceio
# Processing Record 29 of Set 6 | tiksi
# Processing Record 30 of Set 6 | pevek
# Processing Record 31 of Set 6 | ulaangom
# Processing Record 32 of Set 6 | hailar
# Processing Record 33 of Set 6 | mujiayingzi
# Processing Record 34 of Set 6 | voyvozh
# Processing Record 35 of Set 6 | havelock
# Processing Record 36 of Set 6 | itoman
# Processing Record 37 of Set 6 | ahipara
# Processing Record 38 of Set 6 | chipinge
# Processing Record 39 of Set 6 | bintulu
# Processing Record 40 of Set 6 | merrill
# Processing Record 41 of Set 6 | kakonko
# Processing Record 42 of Set 6 | kindersley
# Processing Record 43 of Set 6 | san nicolas
# Processing Record 44 of Set 6 | korla
# Processing Record 45 of Set 6 | udachnyy
# Processing Record 46 of Set 6 | hanyang
# Processing Record 47 of Set 6 | florence
# Processing Record 48 of Set 6 | edd
# Processing Record 49 of Set 6 | seydi
# Processing Record 50 of Set 6 | ukwa
# Processing Record 0 of Set 7 | hervey bay
# Processing Record 1 of Set 7 | san borja
# Processing Record 2 of Set 7 | atikokan
# Processing Record 3 of Set 7 | maarianhamina
# City not found. Skipping...
# Processing Record 4 of Set 7 | dauphin
# Processing Record 5 of Set 7 | buraydah
# Processing Record 6 of Set 7 | cap malheureux
# Processing Record 7 of Set 7 | at-bashi
# Processing Record 8 of Set 7 | broome
# Processing Record 9 of Set 7 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 10 of Set 7 | fairbanks
# Processing Record 11 of Set 7 | sur
# Processing Record 12 of Set 7 | broken hill
# Processing Record 13 of Set 7 | tommot
# Processing Record 14 of Set 7 | bairiki
# Processing Record 15 of Set 7 | kaniama
# Processing Record 16 of Set 7 | richards bay
# Processing Record 17 of Set 7 | chapais
# Processing Record 18 of Set 7 | kamyshevatskaya
# Processing Record 19 of Set 7 | paamiut
# Processing Record 20 of Set 7 | plastun
# Processing Record 21 of Set 7 | palana
# City not found. Skipping...
# Processing Record 22 of Set 7 | yepifan
# Processing Record 23 of Set 7 | noumea
# Processing Record 24 of Set 7 | kedrovyy
# Processing Record 25 of Set 7 | shediac
# Processing Record 26 of Set 7 | pachino
# Processing Record 27 of Set 7 | hay river
# Processing Record 28 of Set 7 | tromso
# Processing Record 29 of Set 7 | ekibastuz
# Processing Record 30 of Set 7 | pangnirtung
# Processing Record 31 of Set 7 | samarai
# Processing Record 32 of Set 7 | letlhakeng
# Processing Record 33 of Set 7 | presidente medici
# Processing Record 34 of Set 7 | nochistlan
# Processing Record 35 of Set 7 | meulaboh
# City not found. Skipping...
# Processing Record 3 of Set 9 | hohoe
# Processing Record 4 of Set 9 | comodoro rivadavia
# Processing Record 5 of Set 9 | saanen
# City not found. Skipping...
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | north bend
# Processing Record 8 of Set 9 | porto santo
# Processing Record 9 of Set 9 | tadine
# Processing Record 10 of Set 9 | stende
# Processing Record 11 of Set 9 | mama
# Processing Record 12 of Set 9 | manutuke
# Processing Record 13 of Set 9 | nacala
# Processing Record 14 of Set 9 | auki
# Processing Record 15 of Set 9 | terrace
# Processing Record 16 of Set 9 | chateaubelair
# Processing Record 17 of Set 9 | port lincoln
# City not found. Skipping...
# Processing Record 18 of Set 9 | nicoya
# Processing Record 19 of Set 9 | katherine
# Processing Record 20 of Set 9 | madang
# Processing Record 21 of Set 9 | dharapuram
# Processing Record 22 of Set 9 | maltahohe
# Processing Record 23 of Set 9 | ostrovnoy
# Processing Record 24 of Set 9 | maralal
# Processing Record 25 of Set 9 | iskateley
# Processing Record 26 of Set 9 | nuuk
# Processing Record 27 of Set 9 | kattivakkam
# Processing Record 28 of Set 9 | moerai
# Processing Record 29 of Set 9 | hovezi
# Processing Record 30 of Set 9 | cabra
# Processing Record 31 of Set 9 | espanola
# Processing Record 32 of Set 9 | acarau
# Processing Record 33 of Set 9 | goderich
# Processing Record 34 of Set 9 | saurimo
# Processing Record 35 of Set 9 | mumford
# Processing Record 36 of Set 9 | jalu
# Processing Record 37 of Set 9 | uruzgan
# Processing Record 38 of Set 9 | ixtapa
# Processing Record 39 of Set 9 | menongue
# Processing Record 40 of Set 9 | hastings
# Processing Record 41 of Set 9 | walvis bay
# Processing Record 42 of Set 9 | yamada
# Processing Record 43 of Set 9 | masuguru
# Processing Record 44 of Set 9 | sechura
# City not found. Skipping...
# Processing Record 45 of Set 9 | athens
# Processing Record 46 of Set 9 | karpathos
# Processing Record 47 of Set 9 | gornyy
# Processing Record 48 of Set 9 | msida
# Processing Record 49 of Set 9 | bathsheba
# Processing Record 50 of Set 9 | santiago de cao
# Processing Record 0 of Set 10 | praxedis guerrero
# Processing Record 1 of Set 10 | locri
# Processing Record 2 of Set 10 | cidreira
# Processing Record 3 of Set 10 | khuzhir
# Processing Record 4 of Set 10 | saraland
# Processing Record 5 of Set 10 | bull savanna
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | sangin
# Processing Record 8 of Set 10 | tres arroyos
# Processing Record 9 of Set 10 | badarwas
# Processing Record 10 of Set 10 | basco
# Processing Record 11 of Set 10 | sulangan
# Processing Record 12 of Set 10 | orel-izumrud
# Processing Record 13 of Set 10 | wana
# Processing Record 14 of Set 10 | luocheng
# Processing Record 15 of Set 10 | santa cruz
# Processing Record 16 of Set 10 | poronaysk
# Processing Record 17 of Set 10 | doha
# Processing Record 18 of Set 10 | svetlogorsk
# Processing Record 19 of Set 10 | hovd
# Processing Record 20 of Set 10 | pine bluff
# Processing Record 21 of Set 10 | orcopampa
# Processing Record 22 of Set 10 | kapoeta
# Processing Record 23 of Set 10 | cordoba
# Processing Record 24 of Set 10 | jacksonville
# Processing Record 25 of Set 10 | lerik
# Processing Record 26 of Set 10 | lake jackson
# Processing Record 27 of Set 10 | isangel
# Processing Record 28 of Set 10 | constantine
# Processing Record 29 of Set 10 | ulkan
# Processing Record 30 of Set 10 | tomatlan
# Processing Record 31 of Set 10 | mahon
# Processing Record 32 of Set 10 | atkarsk
# Processing Record 33 of Set 10 | san andres
# Processing Record 34 of Set 10 | pak thong chai
# Processing Record 35 of Set 10 | kuito
# Processing Record 36 of Set 10 | englewood
# Processing Record 37 of Set 10 | burgos
# Processing Record 38 of Set 10 | palmer
# Processing Record 39 of Set 10 | casablanca
# Processing Record 40 of Set 10 | gigmoto
# Processing Record 41 of Set 10 | pangai
# City not found. Skipping...
# Processing Record 42 of Set 10 | saint-georges
# Processing Record 43 of Set 10 | nyahururu
# Processing Record 44 of Set 10 | aklavik
# Processing Record 45 of Set 10 | muriti
# City not found. Skipping...
# Processing Record 46 of Set 10 | arkhara
# Processing Record 47 of Set 10 | zhezkazgan
# Processing Record 48 of Set 10 | trelew
# Processing Record 49 of Set 10 | qiongshan
# Processing Record 50 of Set 10 | fez
# Processing Record 0 of Set 11 | marzuq
# Processing Record 1 of Set 11 | charters towers
# Processing Record 2 of Set 11 | suntar
# Processing Record 3 of Set 11 | huanren
# Processing Record 4 of Set 11 | saint-francois
# Processing Record 5 of Set 11 | margate
# Processing Record 6 of Set 11 | port keats
# Processing Record 7 of Set 11 | ovsyanka
# Processing Record 8 of Set 11 | kemijarvi
# Processing Record 9 of Set 11 | andros town
# Processing Record 10 of Set 11 | medvode
# Processing Record 11 of Set 11 | luangwa
# Processing Record 12 of Set 11 | maniitsoq
# Processing Record 13 of Set 11 | ryazan
# Processing Record 14 of Set 11 | stockport
# Processing Record 15 of Set 11 | balkanabat
# Processing Record 16 of Set 11 | benguela
# Processing Record 17 of Set 11 | sirari
# Processing Record 18 of Set 11 | chirongui
# Processing Record 19 of Set 11 | smirnykh
# Processing Record 20 of Set 11 | vostok
# Processing Record 21 of Set 11 | esmeralda
# Processing Record 22 of Set 11 | mount pleasant
# Processing Record 23 of Set 11 | puerto rondon
# Processing Record 24 of Set 11 | port macquarie
# Processing Record 25 of Set 11 | pilar
# Processing Record 26 of Set 11 | bubaque
# Processing Record 27 of Set 11 | krasnoarmeysk
# Processing Record 28 of Set 11 | biak
# Processing Record 29 of Set 11 | san jose
# Processing Record 30 of Set 11 | lander
# Processing Record 31 of Set 11 | savannah bight
# Processing Record 32 of Set 11 | zaton
# Processing Record 33 of Set 11 | rundu
# Processing Record 34 of Set 11 | betare oya
# Processing Record 35 of Set 11 | roald
# Processing Record 36 of Set 11 | suratgarh
# Processing Record 37 of Set 11 | kanigoro
# Processing Record 38 of Set 11 | grand gaube
# Processing Record 39 of Set 11 | kayerkan
# Processing Record 40 of Set 11 | diffa
# City not found. Skipping...
# Processing Record 41 of Set 11 | zyryanka
# Processing Record 42 of Set 11 | mikhaylovskoye
# Processing Record 43 of Set 11 | narsaq
# Processing Record 44 of Set 11 | gwadar
# Processing Record 45 of Set 11 | praia
# Processing Record 46 of Set 11 | bontang
# Processing Record 47 of Set 11 | chilliwack
# Processing Record 48 of Set 11 | manacapuru
# Processing Record 49 of Set 11 | zahesi
# Processing Record 50 of Set 11 | kirando
# Processing Record 0 of Set 12 | chicama
# Processing Record 1 of Set 12 | haines junction
# Processing Record 2 of Set 12 | belmonte
# Processing Record 3 of Set 12 | port augusta
# Processing Record 4 of Set 12 | saint-pierre
# City not found. Skipping...
# Processing Record 5 of Set 12 | ukiah
# Processing Record 6 of Set 12 | namatanai
# Processing Record 7 of Set 12 | vestmannaeyjar
# Processing Record 8 of Set 12 | opuwo
# Processing Record 9 of Set 12 | siyabuswa
# Processing Record 10 of Set 12 | vysokogornyy
# Processing Record 11 of Set 12 | ust-nera
# Processing Record 12 of Set 12 | longhua
# Processing Record 13 of Set 12 | belgrade
# Processing Record 14 of Set 12 | lucapa
# Processing Record 15 of Set 12 | dakar
# City not found. Skipping...
# Processing Record 16 of Set 12 | storm lake
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame
city_df = pd.DataFrame({"City": city_name, "Lat": city_lat , "Lng": city_lng, "Max Temp": max_temp, "Humidity": humidity , 
                        "Cloudiness":cloudiness , "Wind Speed":wind_speed, "Country":country , "Date":date  })
city_df.to_csv("output_data/city_df.csv", index = False)

# %%
city_df.head()
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Rikitea -23.12 -134.97     25.24        78         100        5.55
# 1   Øksfjord  70.24   22.35      0.00        93         100        9.30
# 2       Lebu -37.62  -73.65     13.30        89         100        2.46
# 3   Tasiilaq  65.61  -37.64     -2.00        74         100        0.50
# 4  Zavitinsk  50.12  129.45    -18.41        91          92        2.16
#
#   Country        Date
# 0      PF  1607740424
# 1      NO  1607740424
# 2      CL  1607740424
# 3      GL  1607740425
# 4      RU  1607740425

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  577.000000  577.000000  577.000000  577.000000  577.000000  577.000000
# mean    21.219029   19.161352   10.414107   76.824957   53.656846    3.457054
# std     32.722840   90.586432   16.016556   17.646083   40.218070    2.633918
# min    -54.800000 -175.200000  -38.130000   16.000000    0.000000    0.130000
# 25%     -5.360000  -63.600000   -0.560000   69.000000    6.000000    1.500000
# 50%     27.020000   24.730000   14.790000   81.000000   66.000000    2.600000
# 75%     49.200000  101.770000   23.630000   90.000000   91.000000    4.700000
# max     78.220000  179.320000   34.440000  100.000000  100.000000   16.000000
#
#                Date
# count  5.770000e+02
# mean   1.607740e+09
# std    7.370909e+01
# min    1.607740e+09
# 25%    1.607740e+09
# 50%    1.607740e+09
# 75%    1.607740e+09
# max    1.607741e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ### NOTE: per the column Humidty and Row max, there are not any cities that have a humidity > 100%. THIS SECTION WAS SKIPPED PER THE INSTRUCTIONS.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Adding the date to the title using when the API was called.
from datetime import datetime
now = datetime.now()
timestamp = datetime.timestamp(now)
dt_object = datetime.fromtimestamp(timestamp)
print("datetime = ", dt_object)
# Out:
# datetime =  2020-12-11 20:35:52.076525

# %%
plt.scatter(city_lat, max_temp, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Max Temperature ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_Temp.png')

# %% [markdown]
# ### The Latitude vs. Temperature Plot plot shows that the temperatures in cities from the Northern Hemisphere tend to drop in temperature during the month of December 2020 than those cities below the 0 degrees mark or Southern Hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_lat, humidity, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Humidity ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_humidity.png')

# %% [markdown]
# ### Latitude vs. Humidity Plot shows that there are more cities from the Northern Hemisphere that have more humidity during the month of December 2020 than those cities below the 0 degrees mark or Southern Hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_lat, cloudiness, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Cloudiness ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_cloudiness.png')

# %% [markdown]
# ### Latitude vs. Cloudiness Plot shows that there are slightly more clouds above the cities from the Northern Hemisphere (above the 0 degree mark) than the Southern Hemisphere during the month of December 2020.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_lat, wind_speed, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Wind Speed ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_windspeed.png')

# %% [markdown]
# ### Latitude vs. Wind Speed Plot shows that there are generally wind speeds of 0-6 mph within cities from both the Northern Hemisphere (above the 0 degree mark latitude) and Southern Hemisphere during the month of December 2020.###

# %% [markdown]
# ## Linear Regression

# %%
# Creating Northern and Southern Hemisphere Dataframes
N_hemisphere = city_df.loc[city_df['Lat']>=0]
S_hemisphere = city_df.loc[city_df['Lat']<0]

# %%
import scipy.stats as st

# %%
N_hemisphere
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1      Øksfjord  70.24   22.35      0.00        93         100        9.30
# 3      Tasiilaq  65.61  -37.64     -2.00        74         100        0.50
# 4     Zavitinsk  50.12  129.45    -18.41        91          92        2.16
# 6        Khilok  51.37  110.47    -17.04        88         100        4.67
# 8       Iralaya  15.00  -83.23     24.55        88           2        3.66
# ..          ...    ...     ...       ...       ...         ...         ...
# 571    Ust-Nera  64.57  143.20    -38.13        72          25        0.41
# 572     Longhua  23.61  114.19     22.49        48          66        1.66
# 573    Belgrade  44.80   20.47      4.00       100          90        2.10
# 575       Dakar  14.69  -17.44     22.00        73           0        5.70
# 576  Storm Lake  42.64  -95.21      1.00        80          90       10.30
#
#     Country        Date
# 1        NO  1607740424
# 3        GL  1607740425
# 4        RU  1607740425
# 6        RU  1607740425
# 8        HN  1607740425
# ..      ...         ...
# 571      RU  1607740522
# 572      CN  1607740522
# 573      RS  1607740203
# 575      SN  1607740522
# 576      US  1607740254
#
# [407 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(0,-30),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.show()
plt.savefig('output_data/N_hemisphere_maxtemp.png')
# Out:
# The r-value is -0.8415959012878118

# %% [markdown]
# ### The Northern Hemisphere - Max Temp vs. Latitude Linear Regression plot and negative r-value shows that there is a negative correlation. The further away a city is from the equator (0 degrees latitude) the colder it is. Temperature doesen't increase along with Latitude increase, thus the correlation is negative.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_maxtemp.png')
plt.show()
# Out:
# The r-value is 0.4458034253555973

# %% [markdown]
# ### The Southern Hemisphere - Max Temp vs. Latitude Linear Regression plot and positive r-value shows that there is a positive correlation. The closer the city is to the equator, the hotter the city is. Both latitude and Temp increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Humidity'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.32938578936444807

# %% [markdown]
# ### The Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The further away the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Humidity'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.330436272509675

# %% [markdown]
# ### The Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The closer the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.2869214877503039

# %% [markdown]
# ### The Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The further away the city is to the equator, the % of cloudiness increases. Both latitude and cloud increase show a positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.1208160647565263

# %% [markdown]
# ### The Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression plot and r-value show that there is a positive correlation. The closer the city is to the equator, the % of cloudiness increases. The indication that both latitude and cloud increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(0,13),fontsize=15,color="red")
plt.ylabel('Wind Speed ')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is 0.17621019568937638

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ### The Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and positive, but low r-value show that there is a weak correlation. The r-value is almost 0 and the line is almost flat. The wind speed increases ever so slightly as the latitude increases. Both latitude and windspeed increase showing a weak correlation.

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,13),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is -0.41119395144968496

# %% [markdown]
# ### The Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and negative r-value show that there is a negative correlation. The wind speed decreases as the latitude increases closer to the equator. Latitude increase and windspeed decrease show a negative correlation.
