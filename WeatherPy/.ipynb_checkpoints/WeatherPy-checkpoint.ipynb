# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = 'output_data/cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url + city).json()
# Taking a look at the data for a city
print(response)
# Out:
# {'coord': {'lon': -34.81, 'lat': -7.47}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 24, 'feels_like': 27.94, 'temp_min': 24, 'temp_max': 24, 'pressure': 1013, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1607665353, 'sys': {'type': 1, 'id': 8391, 'country': 'BR', 'sunrise': 1607673383, 'sunset': 1607718555}, 'timezone': -10800, 'id': 3391889, 'name': 'Pitimbu', 'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set up lists to hold response info
city_name = []
city_lat = []
city_lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
index_counter = 0
set_counter = 1

# %%
print('Beginning Data Retrieval ')
print('-----------------------------')

# Loop through the list of cities and perform a request for data on each...
for index, city in enumerate(cities):
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    response = requests.get(query_url + city).json()
    try:
       
        city_name.append(response['name'])
        city_lat.append(response['coord']['lat'])
        city_lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        else:
            index_counter = index_counter + 1
  
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}")
    except:
        print('City not found. Skipping...')
        
print('-----------------------------')
print('Data Retrieval Complete ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | boden
# Processing Record 2 of Set 1 | kaoma
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | diamantino
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | veraval
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | husavik
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | phonhong
# Processing Record 13 of Set 1 | san andres
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | ostersund
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | bonthe
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | kiunga
# Processing Record 28 of Set 1 | belaya gora
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | lagoa
# Processing Record 35 of Set 1 | kargat
# Processing Record 36 of Set 1 | mao
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | komsomolskiy
# Processing Record 40 of Set 1 | northam
# Processing Record 41 of Set 1 | dakar
# Processing Record 42 of Set 1 | itoman
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | tsogni
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | norman wells
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | karratha
# Processing Record 40 of Set 4 | morehead
# Processing Record 41 of Set 4 | vestmannaeyjar
# Processing Record 42 of Set 4 | kipushi
# Processing Record 43 of Set 4 | dalen
# Processing Record 44 of Set 4 | kaifeng
# City not found. Skipping...
# Processing Record 45 of Set 4 | mehamn
# Processing Record 46 of Set 4 | yerbogachen
# Processing Record 47 of Set 4 | sambava
# Processing Record 48 of Set 4 | los llanos de aridane
# Processing Record 49 of Set 4 | carndonagh
# Processing Record 50 of Set 4 | aksarka
# Processing Record 0 of Set 5 | muravlenko
# Processing Record 1 of Set 5 | iralaya
# Processing Record 2 of Set 5 | kondoa
# Processing Record 3 of Set 5 | rawson
# Processing Record 4 of Set 5 | pacifica
# Processing Record 5 of Set 5 | trinidad
# Processing Record 6 of Set 5 | narsaq
# Processing Record 7 of Set 5 | tazovskiy
# Processing Record 8 of Set 5 | fort saint james
# Processing Record 9 of Set 5 | pathein
# Processing Record 10 of Set 5 | lompoc
# Processing Record 11 of Set 5 | mabaruma
# Processing Record 12 of Set 5 | maragogi
# Processing Record 13 of Set 5 | acopiara
# Processing Record 14 of Set 5 | paraopeba
# Processing Record 15 of Set 5 | lobito
# Processing Record 16 of Set 5 | bergen
# Processing Record 17 of Set 5 | tuatapere
# City not found. Skipping...
# Processing Record 18 of Set 5 | latung
# Processing Record 19 of Set 5 | lang son
# Processing Record 20 of Set 5 | port hardy
# Processing Record 21 of Set 5 | grajau
# Processing Record 22 of Set 5 | remanso
# Processing Record 23 of Set 5 | cobija
# Processing Record 24 of Set 5 | hamilton
# Processing Record 25 of Set 5 | kamphaeng phet
# Processing Record 26 of Set 5 | sorong
# Processing Record 27 of Set 5 | somotillo
# Processing Record 28 of Set 5 | praya
# Processing Record 29 of Set 5 | kumluca
# Processing Record 30 of Set 5 | san jose
# Processing Record 31 of Set 5 | rio grande
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | vung tau
# Processing Record 34 of Set 5 | east london
# Processing Record 35 of Set 5 | vienna
# Processing Record 36 of Set 5 | barcelona
# Processing Record 37 of Set 5 | abu samrah
# Processing Record 38 of Set 5 | lakselv
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | uniontown
# Processing Record 42 of Set 5 | hoquiam
# Processing Record 43 of Set 5 | macia
# Processing Record 44 of Set 5 | bambanglipuro
# Processing Record 45 of Set 5 | mogadishu
# Processing Record 46 of Set 5 | pangnirtung
# Processing Record 47 of Set 5 | neosho
# Processing Record 48 of Set 5 | broome
# Processing Record 49 of Set 5 | leh
# City not found. Skipping...
# Processing Record 50 of Set 5 | khash
# Processing Record 0 of Set 6 | guerrero negro
# Processing Record 1 of Set 6 | thessalon
# Processing Record 2 of Set 6 | caala
# Processing Record 3 of Set 6 | mimongo
# Processing Record 4 of Set 6 | el prat de llobregat
# Processing Record 5 of Set 6 | shingu
# Processing Record 6 of Set 6 | cherskiy
# Processing Record 7 of Set 6 | karakol
# Processing Record 8 of Set 6 | colomi
# Processing Record 9 of Set 6 | selenginsk
# Processing Record 10 of Set 6 | chongwe
# Processing Record 11 of Set 6 | beloha
# Processing Record 12 of Set 6 | vardo
# Processing Record 13 of Set 6 | pointe michel
# Processing Record 14 of Set 6 | kargasok
# City not found. Skipping...
# Processing Record 15 of Set 6 | codrington
# Processing Record 16 of Set 6 | vyartsilya
# Processing Record 17 of Set 6 | tasiilaq
# Processing Record 18 of Set 6 | guntakal
# Processing Record 19 of Set 6 | kalabo
# City not found. Skipping...
# Processing Record 20 of Set 6 | ayagoz
# Processing Record 21 of Set 6 | ochamchira
# Processing Record 22 of Set 6 | sangin
# Processing Record 23 of Set 6 | big spring
# Processing Record 24 of Set 6 | fare
# Processing Record 25 of Set 6 | padang
# Processing Record 26 of Set 6 | roma
# Processing Record 27 of Set 6 | cabo san lucas
# City not found. Skipping...
# Processing Record 28 of Set 6 | la rioja
# Processing Record 29 of Set 6 | lewistown
# Processing Record 30 of Set 6 | srandakan
# Processing Record 31 of Set 6 | hithadhoo
# City not found. Skipping...
# Processing Record 32 of Set 6 | bacungan
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 6 | diphu
# Processing Record 34 of Set 6 | havoysund
# Processing Record 35 of Set 6 | cabra
# Processing Record 36 of Set 6 | saint-francois
# Processing Record 37 of Set 6 | umm lajj
# Processing Record 38 of Set 6 | alpinopolis
# Processing Record 39 of Set 6 | charleston
# Processing Record 40 of Set 6 | kilindoni
# Processing Record 41 of Set 6 | khandbari
# Processing Record 42 of Set 6 | yinchuan
# Processing Record 43 of Set 6 | dasoguz
# Processing Record 44 of Set 6 | canberra
# Processing Record 45 of Set 6 | sao joao da barra
# Processing Record 46 of Set 6 | roald
# Processing Record 47 of Set 6 | sorland
# Processing Record 48 of Set 6 | alofi
# Processing Record 49 of Set 6 | krasnoselkup
# Processing Record 50 of Set 6 | narrabri
# Processing Record 0 of Set 7 | dunedin
# Processing Record 1 of Set 7 | soligalich
# Processing Record 2 of Set 7 | caruray
# Processing Record 3 of Set 7 | lichinga
# Processing Record 4 of Set 7 | mundargi
# Processing Record 5 of Set 7 | san policarpo
# Processing Record 6 of Set 7 | saldanha
# Processing Record 7 of Set 7 | san francisco
# Processing Record 8 of Set 7 | labuhan
# Processing Record 9 of Set 7 | sabang
# Processing Record 10 of Set 7 | kang
# Processing Record 11 of Set 7 | kiama
# Processing Record 12 of Set 7 | pringsewu
# City not found. Skipping...
# Processing Record 13 of Set 7 | margate
# Processing Record 14 of Set 7 | suntar
# City not found. Skipping...
# Processing Record 15 of Set 7 | noicattaro
# City not found. Skipping...
# Processing Record 16 of Set 7 | ilulissat
# Processing Record 17 of Set 7 | kupang
# Processing Record 18 of Set 7 | wagar
# Processing Record 19 of Set 7 | guane
# Processing Record 20 of Set 7 | fort nelson
# Processing Record 21 of Set 7 | martapura
# Processing Record 22 of Set 7 | mae sai
# Processing Record 23 of Set 7 | mattru
# Processing Record 24 of Set 7 | ouadda
# Processing Record 25 of Set 7 | cockburn town
# Processing Record 26 of Set 7 | north bend
# Processing Record 27 of Set 7 | maceio
# Processing Record 28 of Set 7 | grindavik
# Processing Record 29 of Set 7 | alpena
# City not found. Skipping...
# Processing Record 47 of Set 8 | nuristan
# Processing Record 48 of Set 8 | henties bay
# Processing Record 49 of Set 8 | georgetown
# Processing Record 50 of Set 8 | kostomuksha
# Processing Record 0 of Set 9 | srednekolymsk
# Processing Record 1 of Set 9 | coari
# Processing Record 2 of Set 9 | coahuayana
# City not found. Skipping...
# Processing Record 3 of Set 9 | quatre cocos
# Processing Record 4 of Set 9 | pekalongan
# Processing Record 5 of Set 9 | dori
# Processing Record 6 of Set 9 | belmonte
# Processing Record 7 of Set 9 | gweta
# Processing Record 8 of Set 9 | tigil
# Processing Record 9 of Set 9 | lakkoma
# Processing Record 10 of Set 9 | bonavista
# Processing Record 11 of Set 9 | bykovo
# Processing Record 12 of Set 9 | christchurch
# City not found. Skipping...
# Processing Record 13 of Set 9 | penzance
# Processing Record 14 of Set 9 | san antonio
# Processing Record 15 of Set 9 | qaqortoq
# Processing Record 16 of Set 9 | boende
# Processing Record 17 of Set 9 | san ramon
# Processing Record 18 of Set 9 | manaus
# Processing Record 19 of Set 9 | cuenca
# Processing Record 20 of Set 9 | sao filipe
# Processing Record 21 of Set 9 | nizhniy baskunchak
# Processing Record 22 of Set 9 | aracati
# Processing Record 23 of Set 9 | eureka
# Processing Record 24 of Set 9 | charlestown
# Processing Record 25 of Set 9 | varnamo
# Processing Record 26 of Set 9 | phuntsholing
# Processing Record 27 of Set 9 | oktyabrskoye
# Processing Record 28 of Set 9 | nelson bay
# Processing Record 29 of Set 9 | ortona
# Processing Record 30 of Set 9 | lavrentiya
# Processing Record 31 of Set 9 | dera ghazi khan
# Processing Record 32 of Set 9 | asau
# Processing Record 33 of Set 9 | liusha
# Processing Record 34 of Set 9 | walvis bay
# Processing Record 35 of Set 9 | chunhuhub
# Processing Record 36 of Set 9 | hofn
# Processing Record 37 of Set 9 | castelldefels
# Processing Record 38 of Set 9 | aasiaat
# Processing Record 39 of Set 9 | khasan
# Processing Record 40 of Set 9 | san pedro de uraba
# Processing Record 41 of Set 9 | kyzyl-suu
# Processing Record 42 of Set 9 | kieta
# Processing Record 43 of Set 9 | romny
# Processing Record 44 of Set 9 | lata
# Processing Record 45 of Set 9 | ahipara
# Processing Record 46 of Set 9 | stillwater
# Processing Record 47 of Set 9 | egvekinot
# Processing Record 48 of Set 9 | norfolk
# Processing Record 49 of Set 9 | priargunsk
# Processing Record 50 of Set 9 | paamiut
# City not found. Skipping...
# Processing Record 0 of Set 10 | hailar
# Processing Record 1 of Set 10 | skibbereen
# Processing Record 2 of Set 10 | american fork
# Processing Record 3 of Set 10 | baruun-urt
# City not found. Skipping...
# Processing Record 4 of Set 10 | sao jose da coroa grande
# Processing Record 5 of Set 10 | vincennes
# Processing Record 6 of Set 10 | wakkanai
# Processing Record 7 of Set 10 | san matias
# Processing Record 8 of Set 10 | noshiro
# City not found. Skipping...
# Processing Record 9 of Set 10 | la paz
# Processing Record 10 of Set 10 | abeche
# Processing Record 11 of Set 10 | vila velha
# Processing Record 12 of Set 10 | ambilobe
# Processing Record 13 of Set 10 | hay river
# Processing Record 14 of Set 10 | voh
# Processing Record 15 of Set 10 | taoudenni
# Processing Record 16 of Set 10 | labrea
# Processing Record 17 of Set 10 | biak
# Processing Record 18 of Set 10 | quballat
# Processing Record 19 of Set 10 | pisco
# Processing Record 20 of Set 10 | san patricio
# Processing Record 21 of Set 10 | matara
# Processing Record 22 of Set 10 | albanel
# Processing Record 23 of Set 10 | huancabamba
# Processing Record 24 of Set 10 | bairiki
# Processing Record 25 of Set 10 | richards bay
# Processing Record 26 of Set 10 | yerofey pavlovich
# Processing Record 27 of Set 10 | limbang
# Processing Record 28 of Set 10 | ati
# Processing Record 29 of Set 10 | sinaloa
# Processing Record 30 of Set 10 | russell
# Processing Record 31 of Set 10 | nam som
# Processing Record 32 of Set 10 | kuytun
# City not found. Skipping...
# Processing Record 33 of Set 10 | champerico
# Processing Record 34 of Set 10 | surt
# Processing Record 35 of Set 10 | mizdah
# Processing Record 36 of Set 10 | verkhnyaya inta
# Processing Record 37 of Set 10 | port augusta
# Processing Record 38 of Set 10 | sisimiut
# Processing Record 39 of Set 10 | saint-junien
# Processing Record 40 of Set 10 | verkhnevilyuysk
# Processing Record 41 of Set 10 | hoshangabad
# Processing Record 42 of Set 10 | laem sing
# Processing Record 43 of Set 10 | abaete
# Processing Record 44 of Set 10 | iwaki
# Processing Record 45 of Set 10 | tshikapa
# Processing Record 46 of Set 10 | mount gambier
# Processing Record 47 of Set 10 | barra velha
# Processing Record 48 of Set 10 | kharagpur
# Processing Record 49 of Set 10 | grand-santi
# City not found. Skipping...
# Processing Record 50 of Set 10 | kuryk
# City not found. Skipping...
# Processing Record 0 of Set 11 | fonte boa
# Processing Record 1 of Set 11 | novyy svit
# Processing Record 2 of Set 11 | oranjemund
# Processing Record 3 of Set 11 | hazorasp
# Processing Record 4 of Set 11 | tougan
# City not found. Skipping...
# Processing Record 5 of Set 11 | port hope
# Processing Record 6 of Set 11 | puerto rico
# City not found. Skipping...
# Processing Record 7 of Set 11 | san cristobal
# Processing Record 8 of Set 11 | tenkodogo
# Processing Record 9 of Set 11 | sept-iles
# Processing Record 10 of Set 11 | salalah
# Processing Record 11 of Set 11 | bafoulabe
# Processing Record 12 of Set 11 | mogzon
# Processing Record 13 of Set 11 | sao geraldo do araguaia
# Processing Record 14 of Set 11 | bulgan
# Processing Record 15 of Set 11 | chokwe
# Processing Record 16 of Set 11 | quebo
# Processing Record 17 of Set 11 | novouzensk
# Processing Record 18 of Set 11 | kristianstad
# Processing Record 19 of Set 11 | ipixuna
# Processing Record 20 of Set 11 | vigrestad
# Processing Record 21 of Set 11 | tevaitoa
# Processing Record 22 of Set 11 | muggia
# Processing Record 23 of Set 11 | san juan
# Processing Record 24 of Set 11 | chama
# Processing Record 25 of Set 11 | baft
# Processing Record 26 of Set 11 | brownsville
# Processing Record 27 of Set 11 | eyl
# Processing Record 28 of Set 11 | lebowakgomo
# Processing Record 29 of Set 11 | filimonovo
# Processing Record 30 of Set 11 | san vicente
# Processing Record 31 of Set 11 | jining
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | firozabad
# Processing Record 34 of Set 11 | ust-tsilma
# Processing Record 35 of Set 11 | alseseca
# Processing Record 36 of Set 11 | santa marta
# Processing Record 37 of Set 11 | bulaevo
# Processing Record 38 of Set 11 | araouane
# Processing Record 39 of Set 11 | awbari
# Processing Record 40 of Set 11 | oskemen
# Processing Record 41 of Set 11 | lensk
# Processing Record 42 of Set 11 | podporozhye
# Processing Record 43 of Set 11 | dongying
# Processing Record 44 of Set 11 | gigmoto
# Processing Record 45 of Set 11 | jaguaribe
# Processing Record 46 of Set 11 | liuzhou
# Processing Record 47 of Set 11 | saint george
# Processing Record 48 of Set 11 | saint-joseph
# Processing Record 49 of Set 11 | taft
# Processing Record 50 of Set 11 | luanda
# Processing Record 0 of Set 12 | bischheim
# Processing Record 1 of Set 12 | aksu
# Processing Record 2 of Set 12 | pitimbu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame
city_df = pd.DataFrame({"City": city_name, "Lat": city_lat , "Lng": city_lng, "Max Temp": max_temp, "Humidity": humidity , 
                        "Cloudiness":cloudiness , "Wind Speed":wind_speed, "Country":country , "Date":date  })
city_df.to_csv("output_data/city_df.csv", index = False)

# %%
city_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Boden  65.83   21.69      1.00        86          90        2.60
# 1       Kaoma -14.78   24.80     21.16        88          71        2.37
# 2     Mataura -46.19  168.86      8.33        91          87        5.81
# 3  Diamantino -14.41  -56.45     22.12        92         100        3.77
# 4   Bathsheba  13.22  -59.52     26.00        78          40        5.10
#
#   Country        Date
# 0      SE  1607665357
# 1      ZM  1607665358
# 2      NZ  1607665358
# 3      BR  1607665358
# 4      BB  1607665358

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000  563.000000
# mean    19.869183   16.917069   11.500906   75.598579   51.120782    3.389822
# std     32.945248   89.261140   16.041284   18.981977   40.137747    2.488774
# min    -54.800000 -179.170000  -37.610000   15.000000    0.000000    0.030000
# 25%     -7.365000  -58.570000    1.110000   65.500000    3.000000    1.500000
# 50%     22.330000   21.690000   16.350000   81.000000   52.000000    2.840000
# 75%     47.125000   94.080000   24.715000   91.000000   91.500000    4.550000
# max     78.220000  178.420000   36.110000  100.000000  100.000000   13.600000
#
#                Date
# count  5.630000e+02
# mean   1.607665e+09
# std    1.073597e+02
# min    1.607665e+09
# 25%    1.607665e+09
# 50%    1.607665e+09
# 75%    1.607665e+09
# max    1.607665e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# NOTE: per the column Humidty and Row max, there aren't any cities that have a humidity > 100%. THIS SECTION WAS SKIPPED PER THE INSTRUCTIONS.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_lat, max_temp, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title(f"City Latitude vs. Max Temperature (12/10/2020)")
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_Temp.png')

# %% [markdown]
# ### The Latitude vs. Temperature Plot plot shows that the temperatures in cities from the Northern Hemisphere tend to drop in temperature during the month of December 2020 than those cities below the 0 degrees mark or Southern Hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_lat, humidity, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title("City Latitude vs. Humidity (12/10/20)")
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_humidity.png')

# %% [markdown]
# ### Latitude vs. Humidity Plot shows that there are more cities from the Northern Hemisphere that have more humidity during the month of December 2020 than those cities below the 0 degrees mark or Southern Hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_lat, cloudiness, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("City Latitude vs. Cloudiness (12/10/20)")
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_cloudiness.png')

# %% [markdown]
# ### Latitude vs. Cloudiness Plot shows that there are slightly more clouds above the cities from the Northern Hemisphere (above the 0 degree mark) than the Southern Hemisphere during the month of December 2020.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_lat, wind_speed, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title("City Latitude vs. Wind Speed(12/10/20)")
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_windspeed.png')

# %% [markdown]
# ### Latitude vs. Wind Speed Plot shows that there are generally wind speeds of 0-6 mph within cities from both the Northern Hemisphere (above the 0 degree mark latitude) and Southern Hemisphere during the month of December 2020.###

# %% [markdown]
# ## Linear Regression

# %%
# Creating Northern and Southern Hemisphere Dataframes
N_hemisphere = city_df.loc[city_df['Lat']>=0]
S_hemisphere = city_df.loc[city_df['Lat']<0]

# %%
import scipy.stats as st

# %%
N_hemisphere
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Boden  65.83   21.69      1.00        86          90        2.60
# 4       Bathsheba  13.22  -59.52     26.00        78          40        5.10
# 6            Hilo  19.73 -155.09     23.00        78          20        2.60
# 7         Verāval  20.90   70.37     24.97        76          92        2.59
# 8    Longyearbyen  78.22   15.64    -11.00        66          75        2.60
# ..            ...    ...     ...       ...       ...         ...         ...
# 555       Liuzhou  24.31  109.39     16.03        58          99        2.31
# 556  Saint George  37.10 -113.58      7.00        36           1        2.10
# 558          Taft  31.75   54.21      3.00        93          20        1.74
# 560     Bischheim  48.62    7.76      1.11        92          90        2.10
# 561          Aksu  41.12   80.26      1.58        77           1        0.86
#
#     Country        Date
# 0        SE  1607665357
# 4        BB  1607665358
# 6        US  1607665358
# 7        IN  1607665358
# 8        SJ  1607665184
# ..      ...         ...
# 555      CN  1607665438
# 556      US  1607665237
# 558      IR  1607665438
# 560      FR  1607665439
# 561      CN  1607665439
#
# [380 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(0,-30),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.show()
plt.savefig('output_data/N_hemisphere_maxtemp.png')
# Out:
# The r-value is -0.8747193600905884

# %% [markdown]
# ### The Northern Hemisphere - Max Temp vs. Latitude Linear Regression plot and negative r-value of -0.874 shows that there is a negative correlation. The further away a city is from the equator (0 degrees latitude) the colder it is. Temperature doesen't increase along with Latitude increase, thus the correlation is negative.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_maxtemp.png')
plt.show()
# Out:
# The r-value is 0.5781638391649357

# %% [markdown]
# ### The Southern Hemisphere - Max Temp vs. Latitude Linear Regression plot and positive r-value of 0.578 shows that there is a positive correlation. The closer the city is to the equator, the hotter the city is. Both latitude and Temp increase showing a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Humidity'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.4280532148352957

# %% [markdown]
# ### The Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value of 0.428 show that there is a positive correlation. The further away the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Humidity'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.251555139443597

# %% [markdown]
# ### The Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value of 0.251 show that there is a positive correlation. The closer the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.3057037231740847

# %% [markdown]
# ### The Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression plot and positive r-value of 0.305 show that there is a positive correlation. The further away the city is to the equator, the % of cloudiness increases. Both latitude and cloud increase show a positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.2622309838377272

# %% [markdown]
# ### The Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression plot and positive r-value of 0.262 show that there is a positive correlation. The closer the city is to the equator, the % of cloudiness increases. Both latitude and cloud increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Wind Speed ')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is 0.06663892246622229

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ### The Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and positive r-value of 0.066 show that there is a positive correlation, although rather small. The r-value is almost 0 and the line is almost flat. The wind speed increases ever so slightly as the latitude increases. Both latitude and windspeed increase show a small positive correlation.

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is -0.3101309264461384

# %% [markdown]
# ### The Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and negative r-value of -0.310 show that there is a negative correlation. The wind speed decreases as the latitude increases closer to the equator. Latitude increase and windspeed decrease show a negative correlation.
