# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os


# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Store csv created in part one into a DataFrame
city_df = pd.read_csv("data/city_df.csv")
city_df.head()
# Out:
#          City    Lat     Lng  Humidity  Cloudiness  Wind Speed Country  \
# 0     Qaanaaq  77.48  -69.36        92         100        2.64      GL
# 1      Hasaki  35.73  140.83        93          75        2.60      JP
# 2         Leh  34.17   77.58        63           0        0.56      IN
# 3     Ushuaia -54.80  -68.30        45          40        7.70      AR
# 4  San Antero   9.37  -75.76        81          69        4.04      CO
#
#          Date  Max Temp
# 0  1607901446    24.836
# 1  1607901167    41.000
# 2  1607901446     3.398
# 3  1607901447    48.200
# 4  1607901447    79.718

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# Heatmap of humidity
locations = city_df[["Lat", "Lng"]]
humidity = city_df["Humidity"]
figure_layout = {'width': '800px',
                'height': '400px',
                'border':'1px solid black',
                'padding': '1px'}
fig = gmaps.figure(layout = figure_layout, center = (46.0,-5.0), zoom_level = 2)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=100, point_radius=5)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', padding='1px', width='800px'))

# %%
city_df.head(100)
# Out:
#              City    Lat     Lng  Humidity  Cloudiness  Wind Speed Country  \
# 0         Qaanaaq  77.48  -69.36        92         100        2.64      GL
# 1          Hasaki  35.73  140.83        93          75        2.60      JP
# 2             Leh  34.17   77.58        63           0        0.56      IN
# 3         Ushuaia -54.80  -68.30        45          40        7.70      AR
# 4      San Antero   9.37  -75.76        81          69        4.04      CO
# ..            ...    ...     ...       ...         ...         ...     ...
# 95  Pimenta Bueno -11.67  -61.19        69          99        0.64      BR
# 96      Sergeevka  53.88   67.42        95          11        4.07      KZ
# 97    Yellowknife  62.46 -114.35        67          20        3.10      CA
# 98       Hamilton  39.18  -84.53        70          90        2.60      US
# 99       Katsuura  35.13  140.30        54          75       10.30      JP
#
#           Date  Max Temp
# 0   1607901446    24.836
# ...

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
perfect_df = city_df[(city_df['Max Temp'] > 70) & (city_df['Max Temp'] < 80)]
perfect_df = perfect_df[perfect_df['Wind Speed'] < 10]
perfect_df = perfect_df[perfect_df['Cloudiness'] <= 0]
hotel_df = perfect_df.dropna()
hotel_df
# Out:
#                      City    Lat     Lng  Humidity  Cloudiness  Wind Speed  \
# 30         Guerrero Negro  27.98 -114.06        21           0        8.51
# 60            New Norfolk -42.78  147.06        43           0        1.34
# 74                Cayenne   4.93  -52.33        88           0        3.31
# 88                  Lagdo   9.05   13.73        38           0        1.50
# 123                Hobart -42.88  147.33        43           0        6.70
# 155                 Bilma  18.69   12.92        22           0        5.14
# 208                 Arlit  18.74    7.39        15           0        3.40
# 210  Makkah al Mukarramah  21.43   39.83        59           0        0.91
# 232                Beloha -25.17   45.05        61           0        5.42
# 237            Kiryat Gat  31.61   34.76        55           0        1.50
# 278            Vila Velha -20.33  -40.29        78           0        5.10
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# make a dataframe to store useful columns
hotel_df = hotel_df.loc[:,['City', 'Country', 'Lat', 'Lng']]
# include a hotel column
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
#                      City Country    Lat     Lng Hotel Name
# 30         Guerrero Negro      MX  27.98 -114.06
# 60            New Norfolk      AU -42.78  147.06
# 74                Cayenne      GF   4.93  -52.33
# 88                  Lagdo      CM   9.05   13.73
# 123                Hobart      AU -42.88  147.33
# 155                 Bilma      NE  18.69   12.92
# 208                 Arlit      NE  18.74    7.39
# 210  Makkah al Mukarramah      SA  21.43   39.83
# 232                Beloha      MG -25.17   45.05
# 237            Kiryat Gat      IL  31.61   34.76
# 278            Vila Velha      BR -20.33  -40.29
# 286               Bhatkal      IN  13.97   74.57
# 293           Bandarbeyla      SO   9.49   50.81
# 323               Salalah      OM  17.02   54.09
# 325              Ampanihy      MG -24.70   44.75
# 343               Koupéla      BF  12.18   -0.35
# 393              Vallenar      CL -28.57  -70.76
# 401                   Sur      OM  22.57   59.53
# ...

# %%
# find the first hotel for each city located within 5000 meters of your coordinates.
for index, row in hotel_df.iterrows():
    try:
        
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        params = {
        "keyword": "hotel",
        "radius": 5000,
        "key": g_key,
        }

        lat = row['Lat']
        lng = row['Lng']

        params['location'] = f"{lat}, {lng}"

        hotel_data = requests.get(base_url, params=params).json()
        
        hotel_df.loc[index, "Hotel Name"] = hotel_data["results"][0]["name"]
        
    except IndexError:
        
        hotel_df.loc[index, "Hotel Name"] = "NaN"
# Hotel names added, but need to get rid of NAN value       
hotel_df
# Out:
#                      City Country    Lat     Lng  \
# 30         Guerrero Negro      MX  27.98 -114.06
# 60            New Norfolk      AU -42.78  147.06
# 74                Cayenne      GF   4.93  -52.33
# 88                  Lagdo      CM   9.05   13.73
# 123                Hobart      AU -42.88  147.33
# 155                 Bilma      NE  18.69   12.92
# 208                 Arlit      NE  18.74    7.39
# 210  Makkah al Mukarramah      SA  21.43   39.83
# 232                Beloha      MG -25.17   45.05
# 237            Kiryat Gat      IL  31.61   34.76
# 278            Vila Velha      BR -20.33  -40.29
# 286               Bhatkal      IN  13.97   74.57
# 293           Bandarbeyla      SO   9.49   50.81
# 323               Salalah      OM  17.02   54.09
# 325              Ampanihy      MG -24.70   44.75
# 343               Koupéla      BF  12.18   -0.35
# 393              Vallenar      CL -28.57  -70.76
# 401                   Sur      OM  22.57   59.53
# ...

# %%
# getting rid of hotels with NAN value
hotel_df.drop(hotel_df.index[hotel_df['Hotel Name'] == 'NaN'], inplace = True)
hotel_df
# Out:
#                      City Country    Lat     Lng  \
# 30         Guerrero Negro      MX  27.98 -114.06
# 60            New Norfolk      AU -42.78  147.06
# 74                Cayenne      GF   4.93  -52.33
# 123                Hobart      AU -42.88  147.33
# 208                 Arlit      NE  18.74    7.39
# 210  Makkah al Mukarramah      SA  21.43   39.83
# 237            Kiryat Gat      IL  31.61   34.76
# 278            Vila Velha      BR -20.33  -40.29
# 286               Bhatkal      IN  13.97   74.57
# 293           Bandarbeyla      SO   9.49   50.81
# 323               Salalah      OM  17.02   54.09
# 325              Ampanihy      MG -24.70   44.75
# 343               Koupéla      BF  12.18   -0.35
# 393              Vallenar      CL -28.57  -70.76
# 401                   Sur      OM  22.57   59.53
# 447          Todos Santos      MX  23.45 -110.22
# 460                Dwārka      IN  22.24   68.97
# 534                Bosaso      SO  11.28   49.18
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
# Add marker layer to map
fig.add_layer(markers)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', padding='1px', width='800px'))
