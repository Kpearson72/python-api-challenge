# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import sys
sys.path.append('../')

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = 'output_data/cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url + city).json()
# Taking a look at the data for a city
print(response)
# Out:
# {'coord': {'lon': -53.46, 'lat': -33.7}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 19.91, 'feels_like': 19.78, 'temp_min': 19.91, 'temp_max': 19.91, 'pressure': 1007, 'humidity': 84, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.65, 'deg': 23}, 'clouds': {'all': 100}, 'dt': 1607837309, 'sys': {'country': 'UY', 'sunrise': 1607847445, 'sunset': 1607899157}, 'timezone': -10800, 'id': 3443061, 'name': 'Chui', 'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set up lists to hold response info
city_name = []
city_lat = []
city_lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
index_counter = 0
set_counter = 1

# %%
print('Beginning Data Retrieval ')
print('-----------------------------')

# Loop through the list of cities and perform a request for data on each...
for index, city in enumerate(cities):
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    response = requests.get(query_url + city).json()
    try:
       
        city_name.append(response['name'])
        city_lat.append(response['coord']['lat'])
        city_lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        else:
            index_counter = index_counter + 1
  
        print(f"Processing Record {index_counter} of Set {set_counter} | {city}")
    except:
        print('City not found. Skipping...')
        
print('-----------------------------')
print('Data Retrieval Complete ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | kruisfontein
# Processing Record 4 of Set 1 | luderitz
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | paramonga
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | port blair
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | beringovskiy
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | sao felix do xingu
# Processing Record 17 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 18 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 19 of Set 1 | chumikan
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | zhigansk
# Processing Record 23 of Set 1 | coquimbo
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | coari
# Processing Record 26 of Set 1 | alice springs
# Processing Record 27 of Set 1 | bertoua
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | kibondo
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | dracut
# Processing Record 33 of Set 1 | irituia
# Processing Record 34 of Set 1 | noumea
# Processing Record 35 of Set 1 | roding
# Processing Record 36 of Set 1 | constitucion
# Processing Record 37 of Set 1 | lisakovsk
# Processing Record 38 of Set 1 | oranjemund
# Processing Record 39 of Set 1 | mildmay
# Processing Record 40 of Set 1 | asyut
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | bambous virieux
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | namibe
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 34 of Set 4 | zhanaozen
# Processing Record 35 of Set 4 | saint-dizier
# Processing Record 36 of Set 4 | tagusao
# Processing Record 37 of Set 4 | manakara
# Processing Record 38 of Set 4 | vao
# Processing Record 39 of Set 4 | hitoyoshi
# Processing Record 40 of Set 4 | kaitangata
# Processing Record 41 of Set 4 | mehamn
# Processing Record 42 of Set 4 | sabang
# Processing Record 43 of Set 4 | makhinjauri
# Processing Record 44 of Set 4 | bissau
# Processing Record 45 of Set 4 | ureki
# Processing Record 46 of Set 4 | inuvik
# Processing Record 47 of Set 4 | virginia beach
# Processing Record 48 of Set 4 | san jeronimo
# Processing Record 49 of Set 4 | balykshi
# Processing Record 50 of Set 4 | korla
# Processing Record 0 of Set 5 | nanortalik
# Processing Record 1 of Set 5 | adrar
# Processing Record 2 of Set 5 | auki
# Processing Record 3 of Set 5 | grand-santi
# Processing Record 4 of Set 5 | atlantis
# Processing Record 5 of Set 5 | bayevo
# Processing Record 6 of Set 5 | sola
# Processing Record 7 of Set 5 | goderich
# Processing Record 8 of Set 5 | hasanabad
# Processing Record 9 of Set 5 | port lincoln
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | saint pete beach
# Processing Record 12 of Set 5 | ibi
# Processing Record 13 of Set 5 | diplo
# Processing Record 14 of Set 5 | muros
# Processing Record 15 of Set 5 | hambantota
# Processing Record 16 of Set 5 | banff
# Processing Record 17 of Set 5 | ponta do sol
# Processing Record 18 of Set 5 | meulaboh
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | mega
# Processing Record 21 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 5 | whitehorse
# Processing Record 23 of Set 5 | bam
# City not found. Skipping...
# Processing Record 24 of Set 5 | pevek
# Processing Record 25 of Set 5 | fairbanks
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | liku
# Processing Record 28 of Set 5 | pundaguitan
# Processing Record 29 of Set 5 | umm lajj
# Processing Record 30 of Set 5 | flin flon
# Processing Record 31 of Set 5 | chokwe
# Processing Record 32 of Set 5 | erdenet
# Processing Record 33 of Set 5 | varnamo
# Processing Record 34 of Set 5 | komsomolskiy
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | greeneville
# Processing Record 37 of Set 5 | tondano
# City not found. Skipping...
# Processing Record 38 of Set 5 | gat
# Processing Record 39 of Set 5 | walvis bay
# Processing Record 40 of Set 5 | matara
# Processing Record 41 of Set 5 | grindavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 5 | hakkari
# Processing Record 43 of Set 5 | monduli
# Processing Record 44 of Set 5 | lebu
# Processing Record 45 of Set 5 | fayaoue
# Processing Record 46 of Set 5 | portland
# City not found. Skipping...
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | xichang
# Processing Record 49 of Set 5 | okhotsk
# Processing Record 50 of Set 5 | hailar
# Processing Record 0 of Set 6 | codrington
# Processing Record 1 of Set 6 | baykit
# Processing Record 2 of Set 6 | mecca
# Processing Record 3 of Set 6 | boffa
# Processing Record 4 of Set 6 | bud
# Processing Record 5 of Set 6 | porto novo
# Processing Record 6 of Set 6 | vilhena
# Processing Record 7 of Set 6 | bilma
# Processing Record 8 of Set 6 | nhulunbuy
# Processing Record 9 of Set 6 | bousse
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | the valley
# Processing Record 12 of Set 6 | ambon
# Processing Record 13 of Set 6 | grand gaube
# City not found. Skipping...
# Processing Record 14 of Set 6 | kholmsk
# Processing Record 15 of Set 6 | verkhnevilyuysk
# Processing Record 16 of Set 6 | oussouye
# Processing Record 17 of Set 6 | abha
# Processing Record 18 of Set 6 | diamantino
# Processing Record 19 of Set 6 | belaya gora
# Processing Record 20 of Set 6 | guozhen
# City not found. Skipping...
# Processing Record 21 of Set 6 | bagdarin
# Processing Record 22 of Set 6 | novozybkov
# Processing Record 23 of Set 6 | nyurba
# Processing Record 24 of Set 6 | pringsewu
# Processing Record 25 of Set 6 | petaluma
# Processing Record 26 of Set 6 | upernavik
# Processing Record 27 of Set 6 | mucuri
# Processing Record 28 of Set 6 | barabai
# Processing Record 29 of Set 6 | stornoway
# Processing Record 30 of Set 6 | la asuncion
# Processing Record 31 of Set 6 | soyo
# Processing Record 32 of Set 6 | sao joao da barra
# Processing Record 33 of Set 6 | lazaro cardenas
# Processing Record 34 of Set 6 | bougouni
# Processing Record 35 of Set 6 | lagoa
# Processing Record 36 of Set 6 | tailai
# Processing Record 37 of Set 6 | conde
# Processing Record 38 of Set 6 | gusev
# Processing Record 39 of Set 6 | tongliao
# Processing Record 40 of Set 6 | karratha
# Processing Record 41 of Set 6 | belmonte
# Processing Record 42 of Set 6 | cidreira
# Processing Record 43 of Set 6 | ahipara
# Processing Record 44 of Set 6 | benguela
# Processing Record 45 of Set 6 | muroto
# Processing Record 46 of Set 6 | varzea grande
# Processing Record 47 of Set 6 | nanga eboko
# Processing Record 48 of Set 6 | hervey bay
# Processing Record 49 of Set 6 | bulalacao
# Processing Record 50 of Set 6 | brigantine
# Processing Record 0 of Set 7 | matadi
# Processing Record 1 of Set 7 | delfzijl
# Processing Record 2 of Set 7 | iquitos
# Processing Record 3 of Set 7 | pulaski
# Processing Record 4 of Set 7 | carinhanha
# Processing Record 5 of Set 7 | waipawa
# Processing Record 6 of Set 7 | toktogul
# Processing Record 7 of Set 7 | pemangkat
# Processing Record 8 of Set 7 | palomares
# Processing Record 9 of Set 7 | katsuura
# Processing Record 10 of Set 7 | casper
# Processing Record 11 of Set 7 | kandrian
# Processing Record 12 of Set 7 | abu samrah
# Processing Record 13 of Set 7 | evensk
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | taltal
# Processing Record 16 of Set 7 | nikolskoye
# Processing Record 17 of Set 7 | inirida
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | lima
# Processing Record 20 of Set 7 | mitsamiouli
# City not found. Skipping...
# Processing Record 21 of Set 7 | aykhal
# Processing Record 22 of Set 7 | guane
# Processing Record 23 of Set 7 | vardo
# Processing Record 42 of Set 8 | loiza
# City not found. Skipping...
# Processing Record 43 of Set 8 | bonavista
# Processing Record 44 of Set 8 | moron
# Processing Record 45 of Set 8 | horsham
# Processing Record 46 of Set 8 | faya
# Processing Record 47 of Set 8 | flinders
# Processing Record 48 of Set 8 | yumen
# Processing Record 49 of Set 8 | erenhot
# Processing Record 50 of Set 8 | sindi
# Processing Record 0 of Set 9 | port hawkesbury
# Processing Record 1 of Set 9 | chimbote
# Processing Record 2 of Set 9 | hudson bay
# City not found. Skipping...
# Processing Record 3 of Set 9 | kapoeta
# Processing Record 4 of Set 9 | ostrovnoy
# Processing Record 5 of Set 9 | zhezkazgan
# Processing Record 6 of Set 9 | margate
# Processing Record 7 of Set 9 | kaeo
# Processing Record 8 of Set 9 | yulara
# Processing Record 9 of Set 9 | rassvet
# Processing Record 10 of Set 9 | dichiseni
# Processing Record 11 of Set 9 | pudozh
# Processing Record 12 of Set 9 | geraldton
# Processing Record 13 of Set 9 | innisfail
# Processing Record 14 of Set 9 | luancheng
# Processing Record 15 of Set 9 | craig
# City not found. Skipping...
# Processing Record 16 of Set 9 | dayong
# Processing Record 17 of Set 9 | san ramon de la nueva oran
# Processing Record 18 of Set 9 | salima
# Processing Record 19 of Set 9 | bandarbeyla
# Processing Record 20 of Set 9 | alyangula
# Processing Record 21 of Set 9 | yerbogachen
# Processing Record 22 of Set 9 | punta alta
# Processing Record 23 of Set 9 | real
# Processing Record 24 of Set 9 | ilhabela
# City not found. Skipping...
# Processing Record 25 of Set 9 | kenai
# Processing Record 26 of Set 9 | mbalmayo
# Processing Record 27 of Set 9 | yubo
# Processing Record 28 of Set 9 | andenes
# Processing Record 29 of Set 9 | gobabis
# Processing Record 30 of Set 9 | mporokoso
# Processing Record 31 of Set 9 | laerdalsoyri
# Processing Record 32 of Set 9 | nizhniy tsasuchey
# Processing Record 33 of Set 9 | sabha
# Processing Record 34 of Set 9 | yuncheng
# Processing Record 35 of Set 9 | jaru
# Processing Record 36 of Set 9 | brae
# Processing Record 37 of Set 9 | santa cruz
# Processing Record 38 of Set 9 | myaundzha
# Processing Record 39 of Set 9 | sinegorye
# Processing Record 40 of Set 9 | nizwa
# Processing Record 41 of Set 9 | hede
# Processing Record 42 of Set 9 | roald
# Processing Record 43 of Set 9 | kidal
# City not found. Skipping...
# Processing Record 44 of Set 9 | adiake
# Processing Record 45 of Set 9 | taoudenni
# Processing Record 46 of Set 9 | narsaq
# Processing Record 47 of Set 9 | kinablangan
# Processing Record 48 of Set 9 | alzamay
# Processing Record 49 of Set 9 | nouadhibou
# Processing Record 50 of Set 9 | shurugwi
# Processing Record 0 of Set 10 | naze
# Processing Record 1 of Set 10 | arman
# Processing Record 2 of Set 10 | adelaide
# Processing Record 3 of Set 10 | lanigan
# Processing Record 4 of Set 10 | rafaela
# Processing Record 5 of Set 10 | makakilo city
# Processing Record 6 of Set 10 | turukhansk
# Processing Record 7 of Set 10 | katangli
# Processing Record 8 of Set 10 | san marcos
# Processing Record 9 of Set 10 | hornepayne
# Processing Record 10 of Set 10 | hollister
# Processing Record 11 of Set 10 | maloy
# Processing Record 12 of Set 10 | lunenburg
# Processing Record 13 of Set 10 | nuuk
# Processing Record 14 of Set 10 | sao francisco de paula
# Processing Record 15 of Set 10 | ancud
# Processing Record 16 of Set 10 | bubaque
# Processing Record 17 of Set 10 | vilkaviskis
# Processing Record 18 of Set 10 | terney
# Processing Record 19 of Set 10 | opuwo
# Processing Record 20 of Set 10 | nuevitas
# Processing Record 21 of Set 10 | kolvereid
# Processing Record 22 of Set 10 | sao jose da coroa grande
# Processing Record 23 of Set 10 | novoselytsya
# Processing Record 24 of Set 10 | koslan
# Processing Record 25 of Set 10 | mayumba
# Processing Record 26 of Set 10 | fairhope
# Processing Record 27 of Set 10 | shimoda
# Processing Record 28 of Set 10 | shache
# Processing Record 29 of Set 10 | touros
# City not found. Skipping...
# Processing Record 30 of Set 10 | udachnyy
# Processing Record 31 of Set 10 | pinawa
# Processing Record 32 of Set 10 | burnie
# Processing Record 33 of Set 10 | takoradi
# Processing Record 34 of Set 10 | san cristobal
# Processing Record 35 of Set 10 | henties bay
# Processing Record 36 of Set 10 | mandera
# Processing Record 37 of Set 10 | kalashnikovo
# Processing Record 38 of Set 10 | svetlaya
# Processing Record 39 of Set 10 | terrace
# Processing Record 40 of Set 10 | emba
# Processing Record 41 of Set 10 | celestun
# Processing Record 42 of Set 10 | jiwani
# Processing Record 43 of Set 10 | shelburne
# Processing Record 44 of Set 10 | sitka
# Processing Record 45 of Set 10 | san carlos
# Processing Record 46 of Set 10 | oskarshamn
# Processing Record 47 of Set 10 | ust-omchug
# Processing Record 48 of Set 10 | port hardy
# Processing Record 49 of Set 10 | leirvik
# Processing Record 50 of Set 10 | saldanha
# Processing Record 0 of Set 11 | ambunti
# Processing Record 1 of Set 11 | naron
# Processing Record 2 of Set 11 | puerto palomas
# Processing Record 3 of Set 11 | hikari
# Processing Record 4 of Set 11 | manggar
# Processing Record 5 of Set 11 | kabo
# Processing Record 6 of Set 11 | surt
# City not found. Skipping...
# Processing Record 7 of Set 11 | linxia
# Processing Record 8 of Set 11 | gigant
# City not found. Skipping...
# Processing Record 9 of Set 11 | menongue
# Processing Record 10 of Set 11 | severo-yeniseyskiy
# Processing Record 11 of Set 11 | namatanai
# Processing Record 12 of Set 11 | celle
# Processing Record 13 of Set 11 | bontang
# Processing Record 14 of Set 11 | dingle
# Processing Record 15 of Set 11 | oistins
# Processing Record 16 of Set 11 | forrest city
# Processing Record 17 of Set 11 | ellensburg
# City not found. Skipping...
# Processing Record 18 of Set 11 | jijiga
# Processing Record 19 of Set 11 | kamskiye polyany
# Processing Record 20 of Set 11 | napasar
# Processing Record 21 of Set 11 | saraland
# Processing Record 22 of Set 11 | warwick
# City not found. Skipping...
# Processing Record 23 of Set 11 | manokwari
# Processing Record 24 of Set 11 | russell
# Processing Record 25 of Set 11 | haicheng
# Processing Record 26 of Set 11 | cockburn town
# Processing Record 27 of Set 11 | xuchang
# Processing Record 28 of Set 11 | ordu
# Processing Record 29 of Set 11 | ivdel
# Processing Record 30 of Set 11 | vila do maio
# Processing Record 31 of Set 11 | mbandaka
# Processing Record 32 of Set 11 | lucea
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | broome
# Processing Record 35 of Set 11 | bria
# Processing Record 36 of Set 11 | mormugao
# Processing Record 37 of Set 11 | teguldet
# Processing Record 38 of Set 11 | aksu
# Processing Record 39 of Set 11 | okha
# Processing Record 40 of Set 11 | canyon lake
# City not found. Skipping...
# Processing Record 41 of Set 11 | tairua
# Processing Record 42 of Set 11 | shymkent
# Processing Record 43 of Set 11 | korsakov
# Processing Record 44 of Set 11 | kiunga
# Processing Record 45 of Set 11 | maceio
# Processing Record 46 of Set 11 | kununurra
# Processing Record 47 of Set 11 | sao gabriel da cachoeira
# Processing Record 48 of Set 11 | tadine
# Processing Record 49 of Set 11 | aklavik
# Processing Record 50 of Set 11 | jishou
# Processing Record 0 of Set 12 | itarema
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame
city_df = pd.DataFrame({"City": city_name, "Lat": city_lat , "Lng": city_lng, "Max Temp": max_temp, "Humidity": humidity , 
                        "Cloudiness":cloudiness , "Wind Speed":wind_speed, "Country":country , "Date":date  })

# %%
#city_df.head()

# %%
# Converting Celsius to Fahrenheit for changing column max temp to F
def to_fahr(C):
    return (C*9/5) + 32
city_convert_temp = city_df[['Max Temp']].apply(to_fahr)
# Getting list for Fahrenheit temperatures
temp_f = city_convert_temp['Max Temp'].to_list()

# %%
#city_convert_temp

# %%
#adding column of max tem (F) to dataframe
city_df['Max Temp_(F)'] =  city_convert_temp
#city_df

# %%
#dropping max temp for celsius
city_df.drop(['Max Temp'], axis = 1, inplace = True)
#city_df

# %%
# renaming column to Max Temp
city_df.rename(columns = {'Max Temp_(F)': "Max Temp"}, inplace = True)
#Displaying finished DataFrame
city_df
# Out:
#                          City    Lat     Lng  Humidity  Cloudiness  \
# 0                     Mataura -46.19  168.86        80          31
# 1                      Hobart -42.88  147.33        41          75
# 2                Kruisfontein -34.00   24.73        93          20
# 3                    Lüderitz -26.65   15.16        82           0
# 4                      Albany  42.60  -73.97        89         100
# ..                        ...    ...     ...       ...         ...
# 556  São Gabriel da Cachoeira  -0.13  -67.09        96          89
# 557                    Tadine -21.55  167.88        82          98
# 558                   Aklavik  68.22 -135.01        75           0
# 559                    Jishou  28.32  109.72        83         100
# 560                   Itarema  -2.92  -39.92        82          57
#
#      Wind Speed Country        Date  Max Temp
# 0          7.60      NZ  1607837305    53.006
# 1          7.20      AU  1607837120    78.998
# 2          1.92      ZA  1607837307    62.006
# 3          2.60      NA  1607837320    57.200
# 4          2.23      US  1607837308    50.000
# ..          ...     ...         ...       ...
# 556        0.36      BR  1607837372    72.536
# 557        8.35      NC  1607837674    79.952
# 558        1.62      CA  1607837674   -14.800
# 559        4.63      CN  1607837674    43.448
# 560        5.81      BR  1607837389    78.692
#
# [561 rows x 9 columns]

# %%
# Saving dataframe as CSV file in output_data
city_df.to_csv("output_data/city_df.csv", index = False)

# %%
# Using .describe to show statistical data
city_df.describe()
# Out:
#               Lat         Lng    Humidity  Cloudiness  Wind Speed  \
# count  561.000000  561.000000  561.000000  561.000000  561.000000
# mean    19.828093   21.057647   75.748663   56.511586    3.872674
# std     33.337154   90.641382   18.812684   39.349945    2.770627
# min    -54.800000 -175.200000   14.000000    0.000000    0.080000
# 25%     -7.260000  -59.520000   68.000000   18.000000    1.850000
# 50%     22.200000   20.970000   81.000000   73.000000    3.100000
# 75%     48.420000  107.360000   89.000000   96.000000    5.230000
# max     77.480000  179.320000  100.000000  100.000000   14.400000
#
#                Date    Max Temp
# count  5.610000e+02  561.000000
# mean   1.607838e+09   51.042588
# std    1.501234e+02   30.777308
# min    1.607837e+09  -44.266000
# 25%    1.607837e+09   30.992000
# 50%    1.607838e+09   60.800000
# 75%    1.607838e+09   75.164000
# max    1.607838e+09   98.600000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ### NOTE: per the column Humidty and Row max stating 100 is the max for Humidity, there are not any cities that have a humidity > 100%. THIS SECTION WAS SKIPPED PER THE INSTRUCTIONS.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Adding the date to the title using when the API was called.
from datetime import datetime
now = datetime.now()
timestamp = datetime.timestamp(now)
dt_object = datetime.fromtimestamp(timestamp)
print("datetime = ", dt_object)
# Out:
# datetime =  2020-12-12 23:34:35.699884

# %%
# Plotting Latitude vs. Temperature Plot
plt.scatter(city_lat, temp_f, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Max Temperature ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_Temp.png')

# %% [markdown]
# ### The Latitude vs. Temperature Plot plot shows that the temperatures in cities from the Northern Hemisphere tend to drop during the month of December 2020. The cities that are further away from the equator are colder.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plotting Latitude vs. Humidity Plot
plt.scatter(city_lat, humidity, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Humidity ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_humidity.png')

# %% [markdown]
# ### Latitude vs. Humidity Plot shows that there are more cities from the Northern Hemisphere that have a higher % of humidity during the month of December 2020 than those cities below the 0 degrees mark or Southern Hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plotting Latitude vs. Cloudiness Plot
plt.scatter(city_lat, cloudiness, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Cloudiness ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_cloudiness.png')

# %% [markdown]
# ### Latitude vs. Cloudiness Plot shows that the percentage of cloud cover over cities from the Northern Hemisphere is more than the Southern Hemisphere during the month of December 2020.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plotting Latitude vs. Wind Speed Plot
plt.scatter(city_lat, wind_speed, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title(f'City Latitude vs. Wind Speed ({ dt_object.strftime("%D") })')
plt.grid(b=None, which = 'major',axis = 'both')
plt.savefig('output_data/lat_vs_windspeed.png')

# %% [markdown]
# ### Latitude vs. Wind Speed Plot shows that generally wind speeds of 0-6 mph exists both in cities from the Northern Hemisphere and Southern Hemisphere during the month of December 2020.###

# %% [markdown]
# ## Linear Regression

# %%
# Creating Northern and Southern Hemisphere Dataframes
N_hemisphere = city_df.loc[city_df['Lat']>=0]
S_hemisphere = city_df.loc[city_df['Lat']<0]

# %%
import scipy.stats as st

# %%
N_hemisphere
# Out:
#              City    Lat     Lng  Humidity  Cloudiness  Wind Speed Country  \
# 4          Albany  42.60  -73.97        89         100        2.23      US
# 6      Butaritari   3.07  172.79        76          88        5.97      KI
# 7      Port Blair  11.67   92.75        60          28        3.09      IN
# 10   Saint George  37.10 -113.58        32           1        2.60      US
# 11    Clyde River  70.47  -68.59        84          90        3.10      CA
# ..            ...    ...     ...       ...         ...         ...     ...
# 549   Canyon Lake  29.88  -98.26        77           7        2.62      US
# 551      Shymkent  42.30   69.60       100          90        0.75      KZ
# 552      Korsakov  46.63  142.78        62          40        2.00      RU
# 558       Aklavik  68.22 -135.01        75           0        1.62      CA
# 559        Jishou  28.32  109.72        83         100        4.63      CN
#
#            Date  Max Temp
# 4    1607837308    50.000
# 6    1607837590    81.878
# 7    1607837590    82.562
# 10   1607837590    37.400
# 11   1607837590    -0.400
# ..          ...       ...
# 549  1607837671    51.998
# 551  1607837672    26.600
# 552  1607837672    19.400
# 558  1607837674   -14.800
# 559  1607837674    43.448
#
# [379 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere 
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(0,-30),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.show()
plt.savefig('output_data/N_hemisphere_maxtemp.png')
# Out:
# The r-value is -0.8409616207696156

# %% [markdown]
# ### The Northern Hemisphere - Max Temp vs. Latitude Linear Regression plot and negative r-value shows that there is a negative correlation. The further away a city is from the equator (0 degrees latitude) the colder it is. Temperature doesen't increase along with Latitude increase, thus the correlation is negative.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Max Temp'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_maxtemp.png')
plt.show()
# Out:
# The r-value is 0.5775662407862697

# %% [markdown]
# ### The Southern Hemisphere - Max Temp vs. Latitude Linear Regression plot and positive r-value shows that there is a positive correlation. The closer the city is to the equator, the hotter the city is. Both latitude and Temp increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Humidity'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.3317208472733659

# %% [markdown]
# ### The Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The further away the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Humidity'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Humidity'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_humidity.png')
plt.show()
# Out:
# The r-value is 0.2132799220746808

# %% [markdown]
# ### The Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The closer the city is to the equator, the % of humidity increases. Both latitude and humidity increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Cloudiness'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.34060552024586566

# %% [markdown]
# ### The Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression plot and positive r-value show that there is a positive correlation. The further away the city is to the equator, the % of cloudiness increases. Both latitude and cloud increase show a positive correlation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Cloudiness'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Cloudiness'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_cloudiness.png')
plt.show()
# Out:
# The r-value is 0.20561526945070627

# %% [markdown]
# ### The Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression plot and r-value show that there is a positive correlation. The closer the city is to the equator, the % of cloudiness increases. The indication that both latitude and cloud increase show a positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere
correlation = st.pearsonr(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Wind Speed'])
regress_values = N_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(N_hemisphere['Lat'], N_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(N_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(0,13),fontsize=15,color="red")
plt.ylabel('Wind Speed ')
plt.xlabel('Latitude')
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/N_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is 0.15365029146588957

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ### The Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and positive, but low r-value show that there is a weak correlation. The r-value is almost 0 and the line is almost flat. The wind speed increases ever so slightly as the latitude increases. Both latitude and windspeed increase showing a weak correlation.

# %%
# Southern Hemisphere
correlation = st.pearsonr(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Wind Speed'])
regress_values = S_hemisphere['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(S_hemisphere['Lat'], S_hemisphere['Wind Speed'], marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.plot(S_hemisphere['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,13),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.grid(b=None, which = 'major',axis = 'both')
print(f"The r-value is {round(correlation[0],17)}")
plt.savefig('output_data/S_hemisphere_windspeed.png')
plt.show()
# Out:
# The r-value is -0.35189145888171386

# %% [markdown]
# ### The Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression plot and negative r-value show that there is a negative correlation. The wind speed decreases as the latitude increases closer to the equator. Latitude increase and windspeed decrease show a negative correlation.
